# %%
print("ok")
# Out:
# ok

# %%
'''mongodb+srv://khalidasdsju:<db_password>@cluster0.wh4fymj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''
# Out:
# 'mongodb+srv://khalidasdsju:<db_password>@cluster0.wh4fymj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0\n'

# %%
import pandas as pd

# %%
df = pd.read_csv("HF Data.csv", encoding='ISO-8859-1')
df.head()
# Out:
#   StudyID    UHID  SN                 Acute Coronary Syndrome  (ACS)  \
# 0  MPI001  205179   1     ST-Elevation Myocardial Infarction (STEMI)
# 1  MPI002  311074   2     ST-Elevation Myocardial Infarction (STEMI)
# 2  MPI003  530942   3     ST-Elevation Myocardial Infarction (STEMI)
# 3  MPI004    3414   4     ST-Elevation Myocardial Infarction (STEMI)
# 4  MPI005  777747   5     ST-Elevation Myocardial Infarction (STEMI)
#
#   Irregular Heartbeat (Arrhythmia) Bronchial Asthma (BA)  \
# 0                    No Arrhythmia                    No
# 1                    No Arrhythmia                    No
# 2                    No Arrhythmia                    No
# 3                    No Arrhythmia                    No
# 4                    No Arrhythmia                    No
#
#   Coronary Artery Disease (CAD) Chest X-ray (CXR)  \
# 0                        Normal            Normal
# 1                        Normal            Normal
# 2                        Normal            Normal
# 3                        Normal            Normal
# 4                        Normal            Normal
#
#   Dyslipidemia : Abnormal Cholesterol Levels (DL) Diabetes Mellitus (DM)  ...  \
# 0                                              No                     No  ...
# 1                                              No                     No  ...
# 2                                              No                     No  ...
# 3                                              No                    Yes  ...
# 4                                             Yes                     No  ...
#
#   Sodium (mmol/L) (Na) Random Blood Sugar (mg/dL) (RBS)  \
# 0                  140                              4.9
# 1                  137                              6.5
# 2                  139                              4.9
# 3                  141                              5.4
# 4                  141                              6.0
#
#   Systolic Blood Pressure (mmHg) (SBP)  Total Cholesterol (mg/dL) (TC)  \
# 0                                  180                             100
# 1                                  140                             110
# 2                                  140                             130
# 3                                  130                             135
# 4                                  130                             220
#
#   Triglycerides (mg/dL) (TG)  Troponin I (TropI) Weight (kg)   Obisity  \
# 0                         95               0.001          60     Obese
# 1                         85               0.005          64  No Obese
# 2                        100               6.500          85  No Obese
# 3                        120               0.001          66  No Obese
# 4                        190               0.003          70     Obese
#
#   Chest_pain Heart Failure (HF)
# 0     Absent              No HF
# 1     Absent              No HF
# 2     Absent              No HF
# 3     Absent              No HF
# 4     Absent              No HF
#
# [5 rows x 66 columns]

# %%
df.shape
# Out:
# (500, 66)

# %%
df.columns
# Out:
# Index(['StudyID', 'UHID', 'SN', 'Acute Coronary Syndrome  (ACS)',
#        'Irregular Heartbeat (Arrhythmia)', 'Bronchial Asthma (BA)',
#        'Coronary Artery Disease (CAD)', 'Chest X-ray (CXR)',
#        'Dyslipidemia : Abnormal Cholesterol Levels (DL)',
#        'Diabetes Mellitus (DM)', 'Electrocardiogram (ECG)',
#        'Family History of Cardiovascular Disease (FH)', 'Hypertension (HTN)',
#        'Left Ventricular Ejection Fraction (%) (LVEF)',
#        'Myocardial Infarction (Heart Attack) (MI)',
#        'Myocardial Performance Index ( MPI)', 'Mitral Regurgitation (MR)',
#        'Rhythm of Pulse (RP)', 'Recurrent Myocardial Infarction (ReMI)',
#        'Route of Thrombolysis Administration ( RTA)',
#        'Regional Wall Motion Abnormality (RWMA)', 'Gender of the Patient',
#        'Smoking Status', 'Wall Motion Abnormality (Wall)',
#        'Euro Score : Cardiac Surgery Risk Score',
#        'Grace Score : Risk of Death or MI in ACS Patients',
#        'Major Adverse Cardiac Events  (MACES)',
#        'New York Heart Association (NYHA)', 'ST-Segment Resolution  (STR)',
#        'Thrombolysis', 'E/A Ratio (E/A)',
#        'Respiratory Rate (breaths per minute) (RR)', 'Patient's Age',
#        'Absolute Lymphocyte Count (ALC)', 'Body Mass Index (kg/m²) (BMI)',
#        'Brain Natriuretic Peptide (BNP)', 'Chloride (mmol/L) (Cl)',
#        'Kidney Function Marker (mg/dL) : Creatinine',
#        'Diastolic Blood Pressure (mmHg) (DBP)',
#        'Deceleration Time of Mitral Inflow (ms) (DT)',
#        'Fractional Shortening (%) (FS)', 'Hemoglobin (g/dL) (Hb)',
#        'Glycated Hemoglobin (HbA1C)', 'Bicarbonate (mmol/L) (HCO3)',
#        'High-Density Lipoprotein Cholesterol (HDLc)', 'Height (cm or m)',
#        'Heart Rate (HR)', 'Invasive Coronary Treatment (ICT)',
#        'Invasive Revascularization Therapy (IRT)', 'Potassium (mmol/L) (K)',
#        'Left Atrial Volume (mL) (LAV)',
#        'Left Atrial Volume Index (mL/m²) (LAV)',
#        'Low-Density Lipoprotein Cholesterol (LDLc)',
#        'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)',
#        'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)',
#        'LVOT Velocity (LVOT VTI)', 'Sodium (mmol/L) (Na)',
#        'Random Blood Sugar (mg/dL) (RBS)',
#        'Systolic Blood Pressure (mmHg) (SBP)',
#        'Total Cholesterol (mg/dL) (TC)', 'Triglycerides (mg/dL) (TG)',
#        'Troponin I (TropI)', 'Weight (kg)', 'Obisity', 'Chest_pain',
#        'Heart Failure (HF)'],
#       dtype='object')

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'StudyID': 'MPI001',
#   'UHID': 205179,
#   'SN': 1,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 65,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.27,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.6,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.3,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   Mild symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 1.05,
#   'Respiratory Rate (breaths per minute) (RR)': 20,
#   "Patient's Age": 60,
#   'Absolute Lymphocyte Count (ALC)': 2.3,
#   'Body Mass Index (kg/m²) (BMI)': 22.58,
#   'Brain Natriuretic Peptide (BNP)': 15.0,
#   'Chloride (mmol/L) (Cl)': 101,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.93,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 110,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 172,
#   'Fractional Shortening (%) (FS)': 34,
#   'Hemoglobin (g/dL) (Hb)': 13.5,
#   'Glycated Hemoglobin (HbA1C)': 5.6,
#   'Bicarbonate (mmol/L) (HCO3)': 21,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.63,
#   'Heart Rate (HR)': 72,
#   'Invasive Coronary Treatment (ICT)': 88,
#   'Invasive Revascularization Therapy (IRT)': 69,
#   'Potassium (mmol/L) (K)': 3.98,
#   'Left Atrial Volume (mL) (LAV)': 46,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 27.88,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 90,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 36,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24,
#   'LVOT Velocity (LVOT VTI)': 16,
#   'Sodium (mmol/L) (Na)': 140,
#   'Random Blood Sugar (mg/dL) (RBS)': 4.9,
#   'Systolic Blood Pressure (mmHg) (SBP)': 180,
#   'Total Cholesterol (mg/dL) (TC)': 100,
#   'Triglycerides (mg/dL) (TG)': 95,
#   'Troponin I (TropI)': 0.001,
#   'Weight (kg)': 60,
#   'Obisity': 'Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI002',
#   'UHID': 311074,
#   'SN': 2,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 65,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.12,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.4,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.2,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.9,
#   'Respiratory Rate (breaths per minute) (RR)': 18,
#   "Patient's Age": 75,
#   'Absolute Lymphocyte Count (ALC)': 2.6,
#   'Body Mass Index (kg/m²) (BMI)': 22.68,
#   'Brain Natriuretic Peptide (BNP)': 18.0,
#   'Chloride (mmol/L) (Cl)': 105,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.21,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 90,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 236,
#   'Fractional Shortening (%) (FS)': 36,
#   'Hemoglobin (g/dL) (Hb)': 15.1,
#   'Glycated Hemoglobin (HbA1C)': 5.3,
#   'Bicarbonate (mmol/L) (HCO3)': 24,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.68,
#   'Heart Rate (HR)': 90,
#   'Invasive Coronary Treatment (ICT)': 74,
#   'Invasive Revascularization Therapy (IRT)': 92,
#   'Potassium (mmol/L) (K)': 3.8,
#   'Left Atrial Volume (mL) (LAV)': 50,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 28.9,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 85,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 48,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 31,
#   'LVOT Velocity (LVOT VTI)': 17,
#   'Sodium (mmol/L) (Na)': 137,
#   'Random Blood Sugar (mg/dL) (RBS)': 6.5,
#   'Systolic Blood Pressure (mmHg) (SBP)': 140,
#   'Total Cholesterol (mg/dL) (TC)': 110,
#   'Triglycerides (mg/dL) (TG)': 85,
#   'Troponin I (TropI)': 0.005,
#   'Weight (kg)': 64,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI003',
#   'UHID': 530942,
#   'SN': 3,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'Yes',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 62,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.31,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': '   Current',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.5,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.4,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.97,
#   'Respiratory Rate (breaths per minute) (RR)': 19,
#   "Patient's Age": 47,
#   'Absolute Lymphocyte Count (ALC)': 1.8,
#   'Body Mass Index (kg/m²) (BMI)': 28.4,
#   'Brain Natriuretic Peptide (BNP)': 17.0,
#   'Chloride (mmol/L) (Cl)': 105,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.99,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 180,
#   'Fractional Shortening (%) (FS)': 25,
#   'Hemoglobin (g/dL) (Hb)': 11.1,
#   'Glycated Hemoglobin (HbA1C)': 5.7,
#   'Bicarbonate (mmol/L) (HCO3)': 26,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.73,
#   'Heart Rate (HR)': 78,
#   'Invasive Coronary Treatment (ICT)': 60,
#   'Invasive Revascularization Therapy (IRT)': 69,
#   'Potassium (mmol/L) (K)': 3.9,
#   'Left Atrial Volume (mL) (LAV)': 20,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 9.9,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 82,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 39,
#   'LVOT Velocity (LVOT VTI)': 24,
#   'Sodium (mmol/L) (Na)': 139,
#   'Random Blood Sugar (mg/dL) (RBS)': 4.9,
#   'Systolic Blood Pressure (mmHg) (SBP)': 140,
#   'Total Cholesterol (mg/dL) (TC)': 130,
#   'Triglycerides (mg/dL) (TG)': 100,
#   'Troponin I (TropI)': 6.5,
#   'Weight (kg)': 85,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI004',
#   'UHID': 3414,
#   'SN': 4,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 63,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.32,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': '   Female',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.7,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.3,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   Mild symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.82,
#   'Respiratory Rate (breaths per minute) (RR)': 13,
#   "Patient's Age": 73,
#   'Absolute Lymphocyte Count (ALC)': 2.1,
#   'Body Mass Index (kg/m²) (BMI)': 23.38,
#   'Brain Natriuretic Peptide (BNP)': 20.0,
#   'Chloride (mmol/L) (Cl)': 99,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.55,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 60,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 172,
#   'Fractional Shortening (%) (FS)': 33,
#   'Hemoglobin (g/dL) (Hb)': 14.2,
#   'Glycated Hemoglobin (HbA1C)': 6.9,
#   'Bicarbonate (mmol/L) (HCO3)': 37,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.68,
#   'Heart Rate (HR)': 50,
#   'Invasive Coronary Treatment (ICT)': 74,
#   'Invasive Revascularization Therapy (IRT)': 74,
#   'Potassium (mmol/L) (K)': 4.2,
#   'Left Atrial Volume (mL) (LAV)': 22,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 13.1,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 75,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 51,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34,
#   'LVOT Velocity (LVOT VTI)': 23,
#   'Sodium (mmol/L) (Na)': 141,
#   'Random Blood Sugar (mg/dL) (RBS)': 5.4,
#   'Systolic Blood Pressure (mmHg) (SBP)': 130,
#   'Total Cholesterol (mg/dL) (TC)': 135,
#   'Triglycerides (mg/dL) (TG)': 120,
#   'Troponin I (TropI)': 0.001,
#   'Weight (kg)': 66,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI005',
#   'UHID': 777747,
#   'SN': 5,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 60,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.07,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.4,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.2,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.88,
#   'Respiratory Rate (breaths per minute) (RR)': 19,
#   "Patient's Age": 48,
#   'Absolute Lymphocyte Count (ALC)': 2.5,
#   'Body Mass Index (kg/m²) (BMI)': 24.8,
#   'Brain Natriuretic Peptide (BNP)': 22.0,
#   'Chloride (mmol/L) (Cl)': 105,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.9,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 97,
#   'Fractional Shortening (%) (FS)': 32,
#   'Hemoglobin (g/dL) (Hb)': 13.5,
#   'Glycated Hemoglobin (HbA1C)': 4.9,
#   'Bicarbonate (mmol/L) (HCO3)': 24,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.68,
#   'Heart Rate (HR)': 74,
#   'Invasive Coronary Treatment (ICT)': 83,
#   'Invasive Revascularization Therapy (IRT)': 83,
#   'Potassium (mmol/L) (K)': 4.0,
#   'Left Atrial Volume (mL) (LAV)': 32,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 17.71,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 150,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 46,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 31,
#   'LVOT Velocity (LVOT VTI)': 21,
#   'Sodium (mmol/L) (Na)': 141,
#   'Random Blood Sugar (mg/dL) (RBS)': 6.0,
#   'Systolic Blood Pressure (mmHg) (SBP)': 130,
#   'Total Cholesterol (mg/dL) (TC)': 220,
#   'Triglycerides (mg/dL) (TG)': 190,
#   'Troponin I (TropI)': 0.003,
#   'Weight (kg)': 70,
#   'Obisity': 'Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI006',
#   'UHID': 728014,
#   'SN': 6,
#   'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   TVD',
#   'Chest X-ray (CXR)': '   Cardiomegaly',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   T inversion',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 25,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.38,
#   'Mitral Regurgitation (MR)': '   Trivial',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'Ex',
#   'Wall Motion Abnormality (Wall)': '   Anterior',
#   'Euro Score : Cardiac Surgery Risk Score': 21.5,
#   'Grace Score : Risk of Death or MI in ACS Patients': 1.9,
#   'Major Adverse Cardiac Events  (MACES)': 11.6,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 1.34,
#   'Respiratory Rate (breaths per minute) (RR)': 23,
#   "Patient's Age": 23,
#   'Absolute Lymphocyte Count (ALC)': 2.7,
#   'Body Mass Index (kg/m²) (BMI)': 25.71,
#   'Brain Natriuretic Peptide (BNP)': 30.0,
#   'Chloride (mmol/L) (Cl)': 100,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.9,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 177,
#   'Fractional Shortening (%) (FS)': 36,
#   'Hemoglobin (g/dL) (Hb)': 10.3,
#   'Glycated Hemoglobin (HbA1C)': 4.7,
#   'Bicarbonate (mmol/L) (HCO3)': 25,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.65,
#   'Heart Rate (HR)': 78,
#   'Invasive Coronary Treatment (ICT)': 101,
#   'Invasive Revascularization Therapy (IRT)': 74,
#   'Potassium (mmol/L) (K)': 3.8,
#   'Left Atrial Volume (mL) (LAV)': 35,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 19.54,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 95,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 44,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 28,
#   'LVOT Velocity (LVOT VTI)': 18,
#   'Sodium (mmol/L) (Na)': 149,
#   'Random Blood Sugar (mg/dL) (RBS)': 5.8,
#   'Systolic Blood Pressure (mmHg) (SBP)': 120,
#   'Total Cholesterol (mg/dL) (TC)': 157,
#   'Triglycerides (mg/dL) (TG)': 130,
#   'Troponin I (TropI)': 0.001,
#   'Weight (kg)': 70,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI007',
#   'UHID': 778439,
#   'SN': 7,
#   'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   TVD',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   AMI',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 30,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.45,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'MI',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': '   Current',
#   'Wall Motion Abnormality (Wall)': '   Anterior',
#   'Euro Score : Cardiac Surgery Risk Score': 13.9,
#   'Grace Score : Risk of Death or MI in ACS Patients': 1.9,
#   'Major Adverse Cardiac Events  (MACES)': 11.6,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.92,
#   'Respiratory Rate (breaths per minute) (RR)': 21,
#   "Patient's Age": 32,
#   'Absolute Lymphocyte Count (ALC)': 2.8,
#   'Body Mass Index (kg/m²) (BMI)': 22.58,
#   'Brain Natriuretic Peptide (BNP)': 21.0,
#   'Chloride (mmol/L) (Cl)': 104,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.9,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 106,
#   'Fractional Shortening (%) (FS)': 35,
#   'Hemoglobin (g/dL) (Hb)': 11.3,
#   'Glycated Hemoglobin (HbA1C)': 5.4,
#   'Bicarbonate (mmol/L) (HCO3)': 22,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.63,
#   'Heart Rate (HR)': 84,
#   'Invasive Coronary Treatment (ICT)': 101,
#   'Invasive Revascularization Therapy (IRT)': 69,
#   'Potassium (mmol/L) (K)': 3.5,
#   'Left Atrial Volume (mL) (LAV)': 36,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 21.84,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 227,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 44,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 29,
#   'LVOT Velocity (LVOT VTI)': 19,
#   'Sodium (mmol/L) (Na)': 138,
#   'Random Blood Sugar (mg/dL) (RBS)': 6.1,
#   'Systolic Blood Pressure (mmHg) (SBP)': 110,
#   'Total Cholesterol (mg/dL) (TC)': 299,
#   'Triglycerides (mg/dL) (TG)': 58,
#   'Troponin I (TropI)': 0.002,
#   'Weight (kg)': 60,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI008',
#   'UHID': 778449,
#   'SN': 8,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' Yes',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   T inversion',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 60,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.4,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'MI',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.6,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.3,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.78,
#   'Respiratory Rate (breaths per minute) (RR)': 20,
#   "Patient's Age": 70,
#   'Absolute Lymphocyte Count (ALC)': 2.9,
#   'Body Mass Index (kg/m²) (BMI)': 27.43,
#   'Brain Natriuretic Peptide (BNP)': 24.0,
#   'Chloride (mmol/L) (Cl)': 100,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.09,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 70,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 207,
#   'Fractional Shortening (%) (FS)': 34,
#   'Hemoglobin (g/dL) (Hb)': 13.3,
#   'Glycated Hemoglobin (HbA1C)': 8.5,
#   'Bicarbonate (mmol/L) (HCO3)': 21,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.62,
#   'Heart Rate (HR)': 70,
#   'Invasive Coronary Treatment (ICT)': 59,
#   'Invasive Revascularization Therapy (IRT)': 118,
#   'Potassium (mmol/L) (K)': 4.1,
#   'Left Atrial Volume (mL) (LAV)': 38,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 21.11,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 241,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 49,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 33,
#   'LVOT Velocity (LVOT VTI)': 24,
#   'Sodium (mmol/L) (Na)': 137,
#   'Random Blood Sugar (mg/dL) (RBS)': 12.1,
#   'Systolic Blood Pressure (mmHg) (SBP)': 120,
#   'Total Cholesterol (mg/dL) (TC)': 327,
#   'Triglycerides (mg/dL) (TG)': 271,
#   'Troponin I (TropI)': 6.1,
#   'Weight (kg)': 72,
#   'Obisity': 'Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI009',
#   'UHID': 462024,
#   'SN': 9,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' Yes',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Cardiomegaly',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'Yes',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 60,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.16,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': '   Female',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.4,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.2,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.86,
#   'Respiratory Rate (breaths per minute) (RR)': 20,
#   "Patient's Age": 59,
#   'Absolute Lymphocyte Count (ALC)': 2.3,
#   'Body Mass Index (kg/m²) (BMI)': 25.39,
#   'Brain Natriuretic Peptide (BNP)': 26.0,
#   'Chloride (mmol/L) (Cl)': 101,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.85,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 143,
#   'Fractional Shortening (%) (FS)': 36,
#   'Hemoglobin (g/dL) (Hb)': 12.1,
#   'Glycated Hemoglobin (HbA1C)': 4.7,
#   'Bicarbonate (mmol/L) (HCO3)': 25,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.6,
#   'Heart Rate (HR)': 82,
#   'Invasive Coronary Treatment (ICT)': 74,
#   'Invasive Revascularization Therapy (IRT)': 92,
#   'Potassium (mmol/L) (K)': 4.3,
#   'Left Atrial Volume (mL) (LAV)': 30,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 17.65,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 165,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 45,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 29,
#   'LVOT Velocity (LVOT VTI)': 21,
#   'Sodium (mmol/L) (Na)': 139,
#   'Random Blood Sugar (mg/dL) (RBS)': 6.1,
#   'Systolic Blood Pressure (mmHg) (SBP)': 140,
#   'Total Cholesterol (mg/dL) (TC)': 250,
#   'Triglycerides (mg/dL) (TG)': 210,
#   'Troponin I (TropI)': 0.001,
#   'Weight (kg)': 65,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI010',
#   'UHID': 778732,
#   'SN': 10,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'Yes',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 64,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.14,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': '   Female',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.5,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.4,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   Mild symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 3.39,
#   'Respiratory Rate (breaths per minute) (RR)': 20,
#   "Patient's Age": 70,
#   'Absolute Lymphocyte Count (ALC)': 1.8,
#   'Body Mass Index (kg/m²) (BMI)': 24.46,
#   'Brain Natriuretic Peptide (BNP)': 28.0,
#   'Chloride (mmol/L) (Cl)': 104,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.11,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 244,
#   'Fractional Shortening (%) (FS)': 17,
#   'Hemoglobin (g/dL) (Hb)': 11.1,
#   'Glycated Hemoglobin (HbA1C)': 5.9,
#   'Bicarbonate (mmol/L) (HCO3)': 26,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.63,
#   'Heart Rate (HR)': 102,
#   'Invasive Coronary Treatment (ICT)': 42,
#   'Invasive Revascularization Therapy (IRT)': 88,
#   'Potassium (mmol/L) (K)': 3.9,
#   'Left Atrial Volume (mL) (LAV)': 32,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 18.6,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 150,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 49,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 41,
#   'LVOT Velocity (LVOT VTI)': 19,
#   'Sodium (mmol/L) (Na)': 129,
#   'Random Blood Sugar (mg/dL) (RBS)': 6.8,
#   'Systolic Blood Pressure (mmHg) (SBP)': 120,
#   'Total Cholesterol (mg/dL) (TC)': 210,
#   'Triglycerides (mg/dL) (TG)': 180,
#   'Troponin I (TropI)': 0.0004,
#   'Weight (kg)': 65,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI011',
#   'UHID': 412156,
#   'SN': 11,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 65,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.31,
#   'Mitral Regurgitation (MR)': '   Mild',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': '   Female',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.7,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.3,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   Moderate symptoms',
#   'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 1.24,
#   'Respiratory Rate (breaths per minute) (RR)': 25,
#   "Patient's Age": 60,
#   'Absolute Lymphocyte Count (ALC)': 1.1,
#   'Body Mass Index (kg/m²) (BMI)': 27.76,
#   'Brain Natriuretic Peptide (BNP)': 30.0,
#   'Chloride (mmol/L) (Cl)': 104,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.02,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 100,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 157,
#   'Fractional Shortening (%) (FS)': 21,
#   'Hemoglobin (g/dL) (Hb)': 12.6,
#   'Glycated Hemoglobin (HbA1C)': 6.3,
#   'Bicarbonate (mmol/L) (HCO3)': 27,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.75,
#   'Heart Rate (HR)': 71,
#   'Invasive Coronary Treatment (ICT)': 74,
#   'Invasive Revascularization Therapy (IRT)': 133,
#   'Potassium (mmol/L) (K)': 3.5,
#   'Left Atrial Volume (mL) (LAV)': 35,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 20.0,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 101,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 63,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 50,
#   'LVOT Velocity (LVOT VTI)': 25,
#   'Sodium (mmol/L) (Na)': 140,
#   'Random Blood Sugar (mg/dL) (RBS)': 5.4,
#   'Systolic Blood Pressure (mmHg) (SBP)': 160,
#   'Total Cholesterol (mg/dL) (TC)': 161,
#   'Triglycerides (mg/dL) (TG)': 108,
#   'Troponin I (TropI)': 6.5,
#   'Weight (kg)': 85,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI012',
#   'UHID': 778366,
#   'SN': 12,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 62,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.33,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.4,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.2,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   Moderate symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 1.29,
#   'Respiratory Rate (breaths per minute) (RR)': 18,
#   "Patient's Age": 54,
#   'Absolute Lymphocyte Count (ALC)': 2.1,
#   'Body Mass Index (kg/m²) (BMI)': 27.24,
#   'Brain Natriuretic Peptide (BNP)': 20.0,
#   'Chloride (mmol/L) (Cl)': 106,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.12,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 90,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 249,
#   'Fractional Shortening (%) (FS)': 33,
#   'Hemoglobin (g/dL) (Hb)': 11.7,
#   'Glycated Hemoglobin (HbA1C)': 5.6,
#   'Bicarbonate (mmol/L) (HCO3)': 27,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.58,
#   'Heart Rate (HR)': 72,
#   'Invasive Coronary Treatment (ICT)': 96,
#   'Invasive Revascularization Therapy (IRT)': 133,
#   'Potassium (mmol/L) (K)': 3.2,
#   'Left Atrial Volume (mL) (LAV)': 27,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 17.09,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 95,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 35,
#   'LVOT Velocity (LVOT VTI)': 27,
#   'Sodium (mmol/L) (Na)': 144,
#   'Random Blood Sugar (mg/dL) (RBS)': 5.2,
#   'Systolic Blood Pressure (mmHg) (SBP)': 130,
#   'Total Cholesterol (mg/dL) (TC)': 130,
#   'Triglycerides (mg/dL) (TG)': 75,
#   'Troponin I (TropI)': 0.0001,
#   'Weight (kg)': 68,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI013',
#   'UHID': 777895,
#   'SN': 13,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   Others',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'Yes',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 62,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.04,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'Ex',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.5,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.3,
#   'Major Adverse Cardiac Events  (MACES)': 11.6,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.61,
#   'Respiratory Rate (breaths per minute) (RR)': 25,
#   "Patient's Age": 61,
#   'Absolute Lymphocyte Count (ALC)': 1.9,
#   'Body Mass Index (kg/m²) (BMI)': 35.2,
#   'Brain Natriuretic Peptide (BNP)': 25.0,
#   'Chloride (mmol/L) (Cl)': 107,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.15,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 90,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 109,
#   'Fractional Shortening (%) (FS)': 32,
#   'Hemoglobin (g/dL) (Hb)': 12.5,
#   'Glycated Hemoglobin (HbA1C)': 5.3,
#   'Bicarbonate (mmol/L) (HCO3)': 22,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.45,
#   'Heart Rate (HR)': 84,
#   'Invasive Coronary Treatment (ICT)': 61,
#   'Invasive Revascularization Therapy (IRT)': 84,
#   'Potassium (mmol/L) (K)': 4.0,
#   'Left Atrial Volume (mL) (LAV)': 29,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 16.76,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 165,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 36,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24,
#   'LVOT Velocity (LVOT VTI)': 17,
#   'Sodium (mmol/L) (Na)': 134,
#   'Random Blood Sugar (mg/dL) (RBS)': 5.4,
#   'Systolic Blood Pressure (mmHg) (SBP)': 130,
#   'Total Cholesterol (mg/dL) (TC)': 220,
#   'Triglycerides (mg/dL) (TG)': 195,
#   'Troponin I (TropI)': 0.003,
#   'Weight (kg)': 74,
#   'Obisity': 'Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI014',
#   'UHID': 85541,
#   'SN': 14,
#   'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   DVD',
#   'Chest X-ray (CXR)': '   Cardiomegaly',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   OMI',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'Yes',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 40,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.34,
#   'Mitral Regurgitation (MR)': '   Trivial',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'MI',
#   'Route of Thrombolysis Administration ( RTA)': '   Femoral Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'Ex',
#   'Wall Motion Abnormality (Wall)': '   Antero-Septal',
#   'Euro Score : Cardiac Surgery Risk Score': 19.0,
#   'Grace Score : Risk of Death or MI in ACS Patients': 3.3,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   Mild symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.83,
#   'Respiratory Rate (breaths per minute) (RR)': 20,
#   "Patient's Age": 54,
#   'Absolute Lymphocyte Count (ALC)': 2.2,
#   'Body Mass Index (kg/m²) (BMI)': 33.3,
#   'Brain Natriuretic Peptide (BNP)': 35.0,
#   'Chloride (mmol/L) (Cl)': 106,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.0,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 183,
#   'Fractional Shortening (%) (FS)': 32,
#   'Hemoglobin (g/dL) (Hb)': 11.3,
#   'Glycated Hemoglobin (HbA1C)': 5.3,
#   'Bicarbonate (mmol/L) (HCO3)': 22,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.55,
#   'Heart Rate (HR)': 100,
#   'Invasive Coronary Treatment (ICT)': 83,
#   'Invasive Revascularization Therapy (IRT)': 92,
#   'Potassium (mmol/L) (K)': 3.5,
#   'Left Atrial Volume (mL) (LAV)': 49,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 26.4,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 170,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 51,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34,
#   'LVOT Velocity (LVOT VTI)': 20,
#   'Sodium (mmol/L) (Na)': 141,
#   'Random Blood Sugar (mg/dL) (RBS)': 6.4,
#   'Systolic Blood Pressure (mmHg) (SBP)': 120,
#   'Total Cholesterol (mg/dL) (TC)': 190,
#   'Triglycerides (mg/dL) (TG)': 210,
#   'Troponin I (TropI)': 0.003,
#   'Weight (kg)': 80,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   Killip II'},
#  {'StudyID': 'MPI015',
#   'UHID': 66562,
#   'SN': 15,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 65,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.18,
#   'Mitral Regurgitation (MR)': '   Trivial',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.4,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.1,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.51,
#   'Respiratory Rate (breaths per minute) (RR)': 21,
#   "Patient's Age": 36,
#   'Absolute Lymphocyte Count (ALC)': 3.1,
#   'Body Mass Index (kg/m²) (BMI)': 27.34,
#   'Brain Natriuretic Peptide (BNP)': 20.0,
#   'Chloride (mmol/L) (Cl)': 101,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.91,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 92,
#   'Fractional Shortening (%) (FS)': 35,
#   'Hemoglobin (g/dL) (Hb)': 12.5,
#   'Glycated Hemoglobin (HbA1C)': 6.7,
#   'Bicarbonate (mmol/L) (HCO3)': 24,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.53,
#   'Heart Rate (HR)': 84,
#   'Invasive Coronary Treatment (ICT)': 83,
#   'Invasive Revascularization Therapy (IRT)': 65,
#   'Potassium (mmol/L) (K)': 4.0,
#   'Left Atrial Volume (mL) (LAV)': 49,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 29.71,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 75,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 36,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24,
#   'LVOT Velocity (LVOT VTI)': 20,
#   'Sodium (mmol/L) (Na)': 135,
#   'Random Blood Sugar (mg/dL) (RBS)': 10.5,
#   'Systolic Blood Pressure (mmHg) (SBP)': 130,
#   'Total Cholesterol (mg/dL) (TC)': 150,
#   'Triglycerides (mg/dL) (TG)': 100,
#   'Troponin I (TropI)': 0.03,
#   'Weight (kg)': 64,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   Killip II'},
#  {'StudyID': 'MPI016',
#   'UHID': 778507,
#   'SN': 16,
#   'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   DVD',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   ST Depression',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 45,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.58,
#   'Mitral Regurgitation (MR)': '   Mild',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'MI',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': '   Current',
#   'Wall Motion Abnormality (Wall)': '   Antero-Septal',
#   'Euro Score : Cardiac Surgery Risk Score': 19.0,
#   'Grace Score : Risk of Death or MI in ACS Patients': 3.3,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   Moderate symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 1.48,
#   'Respiratory Rate (breaths per minute) (RR)': 22,
#   "Patient's Age": 60,
#   'Absolute Lymphocyte Count (ALC)': 2.1,
#   'Body Mass Index (kg/m²) (BMI)': 20.03,
#   'Brain Natriuretic Peptide (BNP)': 25.0,
#   'Chloride (mmol/L) (Cl)': 103,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.24,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 368,
#   'Fractional Shortening (%) (FS)': 36,
#   'Hemoglobin (g/dL) (Hb)': 13.1,
#   'Glycated Hemoglobin (HbA1C)': 4.3,
#   'Bicarbonate (mmol/L) (HCO3)': 24,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.58,
#   'Heart Rate (HR)': 82,
#   'Invasive Coronary Treatment (ICT)': 120,
#   'Invasive Revascularization Therapy (IRT)': 115,
#   'Potassium (mmol/L) (K)': 3.9,
#   'Left Atrial Volume (mL) (LAV)': 26,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 17.55,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 175,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34,
#   'LVOT Velocity (LVOT VTI)': 38,
#   'Sodium (mmol/L) (Na)': 149,
#   'Random Blood Sugar (mg/dL) (RBS)': 5.8,
#   'Systolic Blood Pressure (mmHg) (SBP)': 140,
#   'Total Cholesterol (mg/dL) (TC)': 190,
#   'Triglycerides (mg/dL) (TG)': 170,
#   'Troponin I (TropI)': 0.03,
#   'Weight (kg)': 50,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   Killip II'},
#  {'StudyID': 'MPI017',
#   'UHID': 399857,
#   'SN': 17,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   Normal',
#   'Family History of Cardiovascular Disease (FH)': 'Yes',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 65,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.38,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'No',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': '   Current',
#   'Wall Motion Abnormality (Wall)': 'No',
#   'Euro Score : Cardiac Surgery Risk Score': 0.6,
#   'Grace Score : Risk of Death or MI in ACS Patients': 0.3,
#   'Major Adverse Cardiac Events  (MACES)': 0.99,
#   'New York Heart Association (NYHA)': '   Moderate symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.8,
#   'Respiratory Rate (breaths per minute) (RR)': 20,
#   "Patient's Age": 72,
#   'Absolute Lymphocyte Count (ALC)': 2.3,
#   'Body Mass Index (kg/m²) (BMI)': 28.52,
#   'Brain Natriuretic Peptide (BNP)': 15.0,
#   'Chloride (mmol/L) (Cl)': 100,
#   'Kidney Function Marker (mg/dL) : Creatinine': 0.95,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 60,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 121,
#   'Fractional Shortening (%) (FS)': 35,
#   'Hemoglobin (g/dL) (Hb)': 14.2,
#   'Glycated Hemoglobin (HbA1C)': 8.9,
#   'Bicarbonate (mmol/L) (HCO3)': 27,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.6,
#   'Heart Rate (HR)': 78,
#   'Invasive Coronary Treatment (ICT)': 96,
#   'Invasive Revascularization Therapy (IRT)': 104,
#   'Potassium (mmol/L) (K)': 3.9,
#   'Left Atrial Volume (mL) (LAV)': 25,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 15.63,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 65,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 43,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 28,
#   'LVOT Velocity (LVOT VTI)': 25,
#   'Sodium (mmol/L) (Na)': 138,
#   'Random Blood Sugar (mg/dL) (RBS)': 14.1,
#   'Systolic Blood Pressure (mmHg) (SBP)': 100,
#   'Total Cholesterol (mg/dL) (TC)': 120,
#   'Triglycerides (mg/dL) (TG)': 95,
#   'Troponin I (TropI)': 0.001,
#   'Weight (kg)': 73,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI018',
#   'UHID': 697840,
#   'SN': 18,
#   'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '    Normal',
#   'Chest X-ray (CXR)': '   Normal',
# ...
#   'Wall Motion Abnormality (Wall)': '   Inferior+Posterior+RVI',
#   'Euro Score : Cardiac Surgery Risk Score': 10.3,
#   'Grace Score : Risk of Death or MI in ACS Patients': 24.0,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   Mild symptoms',
#   'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 1.23,
#   'Respiratory Rate (breaths per minute) (RR)': 20,
#   "Patient's Age": 50,
#   'Absolute Lymphocyte Count (ALC)': 2.1,
#   'Body Mass Index (kg/m²) (BMI)': 22.94,
#   'Brain Natriuretic Peptide (BNP)': 23.0,
#   'Chloride (mmol/L) (Cl)': 107,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.05,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 90,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 132,
#   'Fractional Shortening (%) (FS)': 20,
#   'Hemoglobin (g/dL) (Hb)': 11.3,
#   'Glycated Hemoglobin (HbA1C)': 5.3,
#   'Bicarbonate (mmol/L) (HCO3)': 20,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.52,
#   'Heart Rate (HR)': 80,
#   'Invasive Coronary Treatment (ICT)': 84,
#   'Invasive Revascularization Therapy (IRT)': 100,
#   'Potassium (mmol/L) (K)': 3.7,
#   'Left Atrial Volume (mL) (LAV)': 41,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 27.41,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 155,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 46,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 37,
#   'LVOT Velocity (LVOT VTI)': 21,
#   'Sodium (mmol/L) (Na)': 145,
#   'Random Blood Sugar (mg/dL) (RBS)': 9.8,
#   'Systolic Blood Pressure (mmHg) (SBP)': 140,
#   'Total Cholesterol (mg/dL) (TC)': 190,
#   'Triglycerides (mg/dL) (TG)': 210,
#   'Troponin I (TropI)': 7.85,
#   'Weight (kg)': 53,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   Killip II'},
#  {'StudyID': 'MPI496',
#   'UHID': 902570,
#   'SN': 496,
#   'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   TVD',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   AMI',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 45,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.1,
#   'Mitral Regurgitation (MR)': '   Nil',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': '   Current',
#   'Wall Motion Abnormality (Wall)': '   Antero-Lateral',
#   'Euro Score : Cardiac Surgery Risk Score': 1.9,
#   'Grace Score : Risk of Death or MI in ACS Patients': 10.0,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   Severe symptoms',
#   'ST-Segment Resolution  (STR)': '   Partial Resolution (<=50%)',
#   'Thrombolysis': '     STK/TNK',
#   'E/A Ratio (E/A)': 0.9,
#   'Respiratory Rate (breaths per minute) (RR)': 22,
#   "Patient's Age": 35,
#   'Absolute Lymphocyte Count (ALC)': 1.3,
#   'Body Mass Index (kg/m²) (BMI)': 29.38,
#   'Brain Natriuretic Peptide (BNP)': 12.0,
#   'Chloride (mmol/L) (Cl)': 99,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.24,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 178,
#   'Fractional Shortening (%) (FS)': 18,
#   'Hemoglobin (g/dL) (Hb)': 11.0,
#   'Glycated Hemoglobin (HbA1C)': 5.3,
#   'Bicarbonate (mmol/L) (HCO3)': 28,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.51,
#   'Heart Rate (HR)': 94,
#   'Invasive Coronary Treatment (ICT)': 92,
#   'Invasive Revascularization Therapy (IRT)': 94,
#   'Potassium (mmol/L) (K)': 3.8,
#   'Left Atrial Volume (mL) (LAV)': 33,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 19.69,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 105,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 48,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 47,
#   'LVOT Velocity (LVOT VTI)': 21,
#   'Sodium (mmol/L) (Na)': 141,
#   'Random Blood Sugar (mg/dL) (RBS)': 6.1,
#   'Systolic Blood Pressure (mmHg) (SBP)': 110,
#   'Total Cholesterol (mg/dL) (TC)': 145,
#   'Triglycerides (mg/dL) (TG)': 110,
#   'Troponin I (TropI)': 13.25,
#   'Weight (kg)': 67,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   Killip III'},
#  {'StudyID': 'MPI497',
#   'UHID': 903670,
#   'SN': 497,
#   'Acute Coronary Syndrome  (ACS)': '   Non-ST-Elevation Myocardial Infarction (NSTEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   TVD',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   T inversion',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 45,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.25,
#   'Mitral Regurgitation (MR)': '   Trivial',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'MI',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': 'Ex',
#   'Wall Motion Abnormality (Wall)': '   Subendocardial',
#   'Euro Score : Cardiac Surgery Risk Score': 4.5,
#   'Grace Score : Risk of Death or MI in ACS Patients': 2.6,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 0.83,
#   'Respiratory Rate (breaths per minute) (RR)': 23,
#   "Patient's Age": 55,
#   'Absolute Lymphocyte Count (ALC)': 2.6,
#   'Body Mass Index (kg/m²) (BMI)': 25.43,
#   'Brain Natriuretic Peptide (BNP)': 35.0,
#   'Chloride (mmol/L) (Cl)': 104,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.3,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 216,
#   'Fractional Shortening (%) (FS)': 48,
#   'Hemoglobin (g/dL) (Hb)': 12.1,
#   'Glycated Hemoglobin (HbA1C)': 5.7,
#   'Bicarbonate (mmol/L) (HCO3)': 24,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.43,
#   'Heart Rate (HR)': 70,
#   'Invasive Coronary Treatment (ICT)': 102,
#   'Invasive Revascularization Therapy (IRT)': 135,
#   'Potassium (mmol/L) (K)': 3.5,
#   'Left Atrial Volume (mL) (LAV)': 33,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 22.96,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 105,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 48,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24,
#   'LVOT Velocity (LVOT VTI)': 22,
#   'Sodium (mmol/L) (Na)': 149,
#   'Random Blood Sugar (mg/dL) (RBS)': 7.8,
#   'Systolic Blood Pressure (mmHg) (SBP)': 120,
#   'Total Cholesterol (mg/dL) (TC)': 160,
#   'Triglycerides (mg/dL) (TG)': 132,
#   'Troponin I (TropI)': 0.223,
#   'Weight (kg)': 52,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Absent',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI498',
#   'UHID': 907432,
#   'SN': 498,
#   'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   DVD',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   AMI',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'No',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 40,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.09,
#   'Mitral Regurgitation (MR)': '   Mild',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': 'Male',
#   'Smoking Status': '   Current',
#   'Wall Motion Abnormality (Wall)': '   Infero+Posterior',
#   'Euro Score : Cardiac Surgery Risk Score': 22.0,
#   'Grace Score : Risk of Death or MI in ACS Patients': 2.1,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   Mild symptoms',
#   'ST-Segment Resolution  (STR)': '   Partial Resolution (<=50%)',
#   'Thrombolysis': '   Pharmacoinvasive',
#   'E/A Ratio (E/A)': 0.79,
#   'Respiratory Rate (breaths per minute) (RR)': 24,
#   "Patient's Age": 70,
#   'Absolute Lymphocyte Count (ALC)': 0.84,
#   'Body Mass Index (kg/m²) (BMI)': 26.84,
#   'Brain Natriuretic Peptide (BNP)': 15.0,
#   'Chloride (mmol/L) (Cl)': 95,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.51,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 203,
#   'Fractional Shortening (%) (FS)': 20,
#   'Hemoglobin (g/dL) (Hb)': 10.1,
#   'Glycated Hemoglobin (HbA1C)': 10.5,
#   'Bicarbonate (mmol/L) (HCO3)': 20,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.52,
#   'Heart Rate (HR)': 78,
#   'Invasive Coronary Treatment (ICT)': 88,
#   'Invasive Revascularization Therapy (IRT)': 129,
#   'Potassium (mmol/L) (K)': 3.9,
#   'Left Atrial Volume (mL) (LAV)': 28,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 17.28,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 160,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 42,
#   'LVOT Velocity (LVOT VTI)': 23,
#   'Sodium (mmol/L) (Na)': 139,
#   'Random Blood Sugar (mg/dL) (RBS)': 16.1,
#   'Systolic Blood Pressure (mmHg) (SBP)': 130,
#   'Total Cholesterol (mg/dL) (TC)': 225,
#   'Triglycerides (mg/dL) (TG)': 105,
#   'Troponin I (TropI)': 9.1,
#   'Weight (kg)': 62,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   Killip II'},
#  {'StudyID': 'MPI499',
#   'UHID': 941097,
#   'SN': 499,
#   'Acute Coronary Syndrome  (ACS)': '   Non-ST-Elevation Myocardial Infarction (NSTEMI)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   TVD with LM',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes',
#   'Diabetes Mellitus (DM)': 'Yes',
#   'Electrocardiogram (ECG)': '   T inversion',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'Yes',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 20,
#   'Myocardial Infarction (Heart Attack) (MI)': 'Yes',
#   'Myocardial Performance Index ( MPI)': 0.17,
#   'Mitral Regurgitation (MR)': '   Trivial',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': '   Female',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': '   Subendocardial',
#   'Euro Score : Cardiac Surgery Risk Score': 19.5,
#   'Grace Score : Risk of Death or MI in ACS Patients': 20.0,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   No symptoms',
#   'ST-Segment Resolution  (STR)': '   No Resolution',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 3.93,
#   'Respiratory Rate (breaths per minute) (RR)': 24,
#   "Patient's Age": 38,
#   'Absolute Lymphocyte Count (ALC)': 3.6,
#   'Body Mass Index (kg/m²) (BMI)': 19.14,
#   'Brain Natriuretic Peptide (BNP)': 38.0,
#   'Chloride (mmol/L) (Cl)': 105,
#   'Kidney Function Marker (mg/dL) : Creatinine': 1.12,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 80,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 107,
#   'Fractional Shortening (%) (FS)': 34,
#   'Hemoglobin (g/dL) (Hb)': 13.1,
#   'Glycated Hemoglobin (HbA1C)': 5.4,
#   'Bicarbonate (mmol/L) (HCO3)': 30,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.6,
#   'Heart Rate (HR)': 110,
#   'Invasive Coronary Treatment (ICT)': 148,
#   'Invasive Revascularization Therapy (IRT)': 134,
#   'Potassium (mmol/L) (K)': 4.1,
#   'Left Atrial Volume (mL) (LAV)': 24,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 16.22,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 164,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 47,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34,
#   'LVOT Velocity (LVOT VTI)': 8,
#   'Sodium (mmol/L) (Na)': 136,
#   'Random Blood Sugar (mg/dL) (RBS)': 5.8,
#   'Systolic Blood Pressure (mmHg) (SBP)': 120,
#   'Total Cholesterol (mg/dL) (TC)': 220,
#   'Triglycerides (mg/dL) (TG)': 236,
#   'Troponin I (TropI)': 0.08,
#   'Weight (kg)': 49,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   No HF'},
#  {'StudyID': 'MPI500',
#   'UHID': 973812,
#   'SN': 500,
#   'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)',
#   'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia',
#   'Bronchial Asthma (BA)': ' No',
#   'Coronary Artery Disease (CAD)': '   TVD',
#   'Chest X-ray (CXR)': '   Normal',
#   'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No',
#   'Diabetes Mellitus (DM)': 'No',
#   'Electrocardiogram (ECG)': '   AMI',
#   'Family History of Cardiovascular Disease (FH)': 'No',
#   'Hypertension (HTN)': 'Yes',
#   'Left Ventricular Ejection Fraction (%) (LVEF)': 30,
#   'Myocardial Infarction (Heart Attack) (MI)': 'No',
#   'Myocardial Performance Index ( MPI)': 0.13,
#   'Mitral Regurgitation (MR)': '   Trivial',
#   'Rhythm of Pulse (RP)': '   Regular',
#   'Recurrent Myocardial Infarction (ReMI)': 'No',
#   'Route of Thrombolysis Administration ( RTA)': '   Radial Route',
#   'Regional Wall Motion Abnormality (RWMA)': 'Yes',
#   'Gender of the Patient': '   Female',
#   'Smoking Status': 'No',
#   'Wall Motion Abnormality (Wall)': '   Anterior',
#   'Euro Score : Cardiac Surgery Risk Score': 8.1,
#   'Grace Score : Risk of Death or MI in ACS Patients': 3.5,
#   'Major Adverse Cardiac Events  (MACES)': 65.2,
#   'New York Heart Association (NYHA)': '   Moderate symptoms',
#   'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)',
#   'Thrombolysis': '   N/A',
#   'E/A Ratio (E/A)': 1.32,
#   'Respiratory Rate (breaths per minute) (RR)': 25,
#   "Patient's Age": 60,
#   'Absolute Lymphocyte Count (ALC)': 2.5,
#   'Body Mass Index (kg/m²) (BMI)': 20.83,
#   'Brain Natriuretic Peptide (BNP)': 25.0,
#   'Chloride (mmol/L) (Cl)': 106,
#   'Kidney Function Marker (mg/dL) : Creatinine': 3.4,
#   'Diastolic Blood Pressure (mmHg) (DBP)': 60,
#   'Deceleration Time of Mitral Inflow (ms) (DT)': 211,
#   'Fractional Shortening (%) (FS)': 24,
#   'Hemoglobin (g/dL) (Hb)': 14.5,
#   'Glycated Hemoglobin (HbA1C)': 5.2,
#   'Bicarbonate (mmol/L) (HCO3)': 25,
#   'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk',
#   'Height (cm or m)': 1.61,
#   'Heart Rate (HR)': 98,
#   'Invasive Coronary Treatment (ICT)': 92,
#   'Invasive Revascularization Therapy (IRT)': 130,
#   'Potassium (mmol/L) (K)': 3.8,
#   'Left Atrial Volume (mL) (LAV)': 31,
#   'Left Atrial Volume Index (mL/m²) (LAV)': 19.95,
#   'Low-Density Lipoprotein Cholesterol (LDLc)': 90,
#   'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 60,
#   'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 46,
#   'LVOT Velocity (LVOT VTI)': 21,
#   'Sodium (mmol/L) (Na)': 137,
#   'Random Blood Sugar (mg/dL) (RBS)': 10.0,
#   'Systolic Blood Pressure (mmHg) (SBP)': 90,
#   'Total Cholesterol (mg/dL) (TC)': 110,
#   'Triglycerides (mg/dL) (TG)': 80,
#   'Troponin I (TropI)': 9.17,
#   'Weight (kg)': 54,
#   'Obisity': 'No Obese',
#   'Chest_pain': 'Present',
#   'Heart Failure (HF)': '   Killip II'}]

# %%
len(data)
# Out:
# 500

# %%
DB_NAME = "HFData"
COLLECTION_NAME = "HFData"
CONNECTION_URL = "mongodb+srv://khalidasdsju:khalidasdsju@cluster0.wh4fymj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('67e6eb53c9af1619f729840d'), 'StudyID': 'MPI001', 'UHID': 205179, 'SN': 1, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 65, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.27, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.6, 'Grace Score : Risk of Death or MI in ACS Patients': 0.3, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   Mild symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 1.05, 'Respiratory Rate (breaths per minute) (RR)': 20, "Patient's Age": 60, 'Absolute Lymphocyte Count (ALC)': 2.3, 'Body Mass Index (kg/m²) (BMI)': 22.58, 'Brain Natriuretic Peptide (BNP)': 15.0, 'Chloride (mmol/L) (Cl)': 101, 'Kidney Function Marker (mg/dL) : Creatinine': 0.93, 'Diastolic Blood Pressure (mmHg) (DBP)': 110, 'Deceleration Time of Mitral Inflow (ms) (DT)': 172, 'Fractional Shortening (%) (FS)': 34, 'Hemoglobin (g/dL) (Hb)': 13.5, 'Glycated Hemoglobin (HbA1C)': 5.6, 'Bicarbonate (mmol/L) (HCO3)': 21, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.63, 'Heart Rate (HR)': 72, 'Invasive Coronary Treatment (ICT)': 88, 'Invasive Revascularization Therapy (IRT)': 69, 'Potassium (mmol/L) (K)': 3.98, 'Left Atrial Volume (mL) (LAV)': 46, 'Left Atrial Volume Index (mL/m²) (LAV)': 27.88, 'Low-Density Lipoprotein Cholesterol (LDLc)': 90, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 36, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24, 'LVOT Velocity (LVOT VTI)': 16, 'Sodium (mmol/L) (Na)': 140, 'Random Blood Sugar (mg/dL) (RBS)': 4.9, 'Systolic Blood Pressure (mmHg) (SBP)': 180, 'Total Cholesterol (mg/dL) (TC)': 100, 'Triglycerides (mg/dL) (TG)': 95, 'Troponin I (TropI)': 0.001, 'Weight (kg)': 60, 'Obisity': 'Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 1: {'_id': ObjectId('67e6eb53c9af1619f729840e'), 'StudyID': 'MPI002', 'UHID': 311074, 'SN': 2, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 65, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.12, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.4, 'Grace Score : Risk of Death or MI in ACS Patients': 0.2, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.9, 'Respiratory Rate (breaths per minute) (RR)': 18, "Patient's Age": 75, 'Absolute Lymphocyte Count (ALC)': 2.6, 'Body Mass Index (kg/m²) (BMI)': 22.68, 'Brain Natriuretic Peptide (BNP)': 18.0, 'Chloride (mmol/L) (Cl)': 105, 'Kidney Function Marker (mg/dL) : Creatinine': 1.21, 'Diastolic Blood Pressure (mmHg) (DBP)': 90, 'Deceleration Time of Mitral Inflow (ms) (DT)': 236, 'Fractional Shortening (%) (FS)': 36, 'Hemoglobin (g/dL) (Hb)': 15.1, 'Glycated Hemoglobin (HbA1C)': 5.3, 'Bicarbonate (mmol/L) (HCO3)': 24, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.68, 'Heart Rate (HR)': 90, 'Invasive Coronary Treatment (ICT)': 74, 'Invasive Revascularization Therapy (IRT)': 92, 'Potassium (mmol/L) (K)': 3.8, 'Left Atrial Volume (mL) (LAV)': 50, 'Left Atrial Volume Index (mL/m²) (LAV)': 28.9, 'Low-Density Lipoprotein Cholesterol (LDLc)': 85, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 48, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 31, 'LVOT Velocity (LVOT VTI)': 17, 'Sodium (mmol/L) (Na)': 137, 'Random Blood Sugar (mg/dL) (RBS)': 6.5, 'Systolic Blood Pressure (mmHg) (SBP)': 140, 'Total Cholesterol (mg/dL) (TC)': 110, 'Triglycerides (mg/dL) (TG)': 85, 'Troponin I (TropI)': 0.005, 'Weight (kg)': 64, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 2: {'_id': ObjectId('67e6eb53c9af1619f729840f'), 'StudyID': 'MPI003', 'UHID': 530942, 'SN': 3, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'Yes', 'Left Ventricular Ejection Fraction (%) (LVEF)': 62, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.31, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': '   Current', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.5, 'Grace Score : Risk of Death or MI in ACS Patients': 0.4, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.97, 'Respiratory Rate (breaths per minute) (RR)': 19, "Patient's Age": 47, 'Absolute Lymphocyte Count (ALC)': 1.8, 'Body Mass Index (kg/m²) (BMI)': 28.4, 'Brain Natriuretic Peptide (BNP)': 17.0, 'Chloride (mmol/L) (Cl)': 105, 'Kidney Function Marker (mg/dL) : Creatinine': 0.99, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 180, 'Fractional Shortening (%) (FS)': 25, 'Hemoglobin (g/dL) (Hb)': 11.1, 'Glycated Hemoglobin (HbA1C)': 5.7, 'Bicarbonate (mmol/L) (HCO3)': 26, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.73, 'Heart Rate (HR)': 78, 'Invasive Coronary Treatment (ICT)': 60, 'Invasive Revascularization Therapy (IRT)': 69, 'Potassium (mmol/L) (K)': 3.9, 'Left Atrial Volume (mL) (LAV)': 20, 'Left Atrial Volume Index (mL/m²) (LAV)': 9.9, 'Low-Density Lipoprotein Cholesterol (LDLc)': 82, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 39, 'LVOT Velocity (LVOT VTI)': 24, 'Sodium (mmol/L) (Na)': 139, 'Random Blood Sugar (mg/dL) (RBS)': 4.9, 'Systolic Blood Pressure (mmHg) (SBP)': 140, 'Total Cholesterol (mg/dL) (TC)': 130, 'Triglycerides (mg/dL) (TG)': 100, 'Troponin I (TropI)': 6.5, 'Weight (kg)': 85, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 3: {'_id': ObjectId('67e6eb53c9af1619f7298410'), 'StudyID': 'MPI004', 'UHID': 3414, 'SN': 4, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 63, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.32, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': '   Female', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.7, 'Grace Score : Risk of Death or MI in ACS Patients': 0.3, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   Mild symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.82, 'Respiratory Rate (breaths per minute) (RR)': 13, "Patient's Age": 73, 'Absolute Lymphocyte Count (ALC)': 2.1, 'Body Mass Index (kg/m²) (BMI)': 23.38, 'Brain Natriuretic Peptide (BNP)': 20.0, 'Chloride (mmol/L) (Cl)': 99, 'Kidney Function Marker (mg/dL) : Creatinine': 1.55, 'Diastolic Blood Pressure (mmHg) (DBP)': 60, 'Deceleration Time of Mitral Inflow (ms) (DT)': 172, 'Fractional Shortening (%) (FS)': 33, 'Hemoglobin (g/dL) (Hb)': 14.2, 'Glycated Hemoglobin (HbA1C)': 6.9, 'Bicarbonate (mmol/L) (HCO3)': 37, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.68, 'Heart Rate (HR)': 50, 'Invasive Coronary Treatment (ICT)': 74, 'Invasive Revascularization Therapy (IRT)': 74, 'Potassium (mmol/L) (K)': 4.2, 'Left Atrial Volume (mL) (LAV)': 22, 'Left Atrial Volume Index (mL/m²) (LAV)': 13.1, 'Low-Density Lipoprotein Cholesterol (LDLc)': 75, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 51, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34, 'LVOT Velocity (LVOT VTI)': 23, 'Sodium (mmol/L) (Na)': 141, 'Random Blood Sugar (mg/dL) (RBS)': 5.4, 'Systolic Blood Pressure (mmHg) (SBP)': 130, 'Total Cholesterol (mg/dL) (TC)': 135, 'Triglycerides (mg/dL) (TG)': 120, 'Troponin I (TropI)': 0.001, 'Weight (kg)': 66, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 4: {'_id': ObjectId('67e6eb53c9af1619f7298411'), 'StudyID': 'MPI005', 'UHID': 777747, 'SN': 5, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 60, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.07, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.4, 'Grace Score : Risk of Death or MI in ACS Patients': 0.2, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.88, 'Respiratory Rate (breaths per minute) (RR)': 19, "Patient's Age": 48, 'Absolute Lymphocyte Count (ALC)': 2.5, 'Body Mass Index (kg/m²) (BMI)': 24.8, 'Brain Natriuretic Peptide (BNP)': 22.0, 'Chloride (mmol/L) (Cl)': 105, 'Kidney Function Marker (mg/dL) : Creatinine': 0.9, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 97, 'Fractional Shortening (%) (FS)': 32, 'Hemoglobin (g/dL) (Hb)': 13.5, 'Glycated Hemoglobin (HbA1C)': 4.9, 'Bicarbonate (mmol/L) (HCO3)': 24, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.68, 'Heart Rate (HR)': 74, 'Invasive Coronary Treatment (ICT)': 83, 'Invasive Revascularization Therapy (IRT)': 83, 'Potassium (mmol/L) (K)': 4.0, 'Left Atrial Volume (mL) (LAV)': 32, 'Left Atrial Volume Index (mL/m²) (LAV)': 17.71, 'Low-Density Lipoprotein Cholesterol (LDLc)': 150, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 46, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 31, 'LVOT Velocity (LVOT VTI)': 21, 'Sodium (mmol/L) (Na)': 141, 'Random Blood Sugar (mg/dL) (RBS)': 6.0, 'Systolic Blood Pressure (mmHg) (SBP)': 130, 'Total Cholesterol (mg/dL) (TC)': 220, 'Triglycerides (mg/dL) (TG)': 190, 'Troponin I (TropI)': 0.003, 'Weight (kg)': 70, 'Obisity': 'Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 5: {'_id': ObjectId('67e6eb53c9af1619f7298412'), 'StudyID': 'MPI006', 'UHID': 728014, 'SN': 6, 'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   TVD', 'Chest X-ray (CXR)': '   Cardiomegaly', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   T inversion', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 25, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.38, 'Mitral Regurgitation (MR)': '   Trivial', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': 'Male', 'Smoking Status': 'Ex', 'Wall Motion Abnormality (Wall)': '   Anterior', 'Euro Score : Cardiac Surgery Risk Score': 21.5, 'Grace Score : Risk of Death or MI in ACS Patients': 1.9, 'Major Adverse Cardiac Events  (MACES)': 11.6, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 1.34, 'Respiratory Rate (breaths per minute) (RR)': 23, "Patient's Age": 23, 'Absolute Lymphocyte Count (ALC)': 2.7, 'Body Mass Index (kg/m²) (BMI)': 25.71, 'Brain Natriuretic Peptide (BNP)': 30.0, 'Chloride (mmol/L) (Cl)': 100, 'Kidney Function Marker (mg/dL) : Creatinine': 0.9, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 177, 'Fractional Shortening (%) (FS)': 36, 'Hemoglobin (g/dL) (Hb)': 10.3, 'Glycated Hemoglobin (HbA1C)': 4.7, 'Bicarbonate (mmol/L) (HCO3)': 25, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.65, 'Heart Rate (HR)': 78, 'Invasive Coronary Treatment (ICT)': 101, 'Invasive Revascularization Therapy (IRT)': 74, 'Potassium (mmol/L) (K)': 3.8, 'Left Atrial Volume (mL) (LAV)': 35, 'Left Atrial Volume Index (mL/m²) (LAV)': 19.54, 'Low-Density Lipoprotein Cholesterol (LDLc)': 95, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 44, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 28, 'LVOT Velocity (LVOT VTI)': 18, 'Sodium (mmol/L) (Na)': 149, 'Random Blood Sugar (mg/dL) (RBS)': 5.8, 'Systolic Blood Pressure (mmHg) (SBP)': 120, 'Total Cholesterol (mg/dL) (TC)': 157, 'Triglycerides (mg/dL) (TG)': 130, 'Troponin I (TropI)': 0.001, 'Weight (kg)': 70, 'Obisity': 'No Obese', 'Chest_pain': 'Present', 'Heart Failure (HF)': '   No HF'}
# 6: {'_id': ObjectId('67e6eb53c9af1619f7298413'), 'StudyID': 'MPI007', 'UHID': 778439, 'SN': 7, 'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   TVD', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   AMI', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 30, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.45, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'MI', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': 'Male', 'Smoking Status': '   Current', 'Wall Motion Abnormality (Wall)': '   Anterior', 'Euro Score : Cardiac Surgery Risk Score': 13.9, 'Grace Score : Risk of Death or MI in ACS Patients': 1.9, 'Major Adverse Cardiac Events  (MACES)': 11.6, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.92, 'Respiratory Rate (breaths per minute) (RR)': 21, "Patient's Age": 32, 'Absolute Lymphocyte Count (ALC)': 2.8, 'Body Mass Index (kg/m²) (BMI)': 22.58, 'Brain Natriuretic Peptide (BNP)': 21.0, 'Chloride (mmol/L) (Cl)': 104, 'Kidney Function Marker (mg/dL) : Creatinine': 0.9, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 106, 'Fractional Shortening (%) (FS)': 35, 'Hemoglobin (g/dL) (Hb)': 11.3, 'Glycated Hemoglobin (HbA1C)': 5.4, 'Bicarbonate (mmol/L) (HCO3)': 22, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.63, 'Heart Rate (HR)': 84, 'Invasive Coronary Treatment (ICT)': 101, 'Invasive Revascularization Therapy (IRT)': 69, 'Potassium (mmol/L) (K)': 3.5, 'Left Atrial Volume (mL) (LAV)': 36, 'Left Atrial Volume Index (mL/m²) (LAV)': 21.84, 'Low-Density Lipoprotein Cholesterol (LDLc)': 227, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 44, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 29, 'LVOT Velocity (LVOT VTI)': 19, 'Sodium (mmol/L) (Na)': 138, 'Random Blood Sugar (mg/dL) (RBS)': 6.1, 'Systolic Blood Pressure (mmHg) (SBP)': 110, 'Total Cholesterol (mg/dL) (TC)': 299, 'Triglycerides (mg/dL) (TG)': 58, 'Troponin I (TropI)': 0.002, 'Weight (kg)': 60, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 7: {'_id': ObjectId('67e6eb53c9af1619f7298414'), 'StudyID': 'MPI008', 'UHID': 778449, 'SN': 8, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' Yes', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   T inversion', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 60, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.4, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'MI', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.6, 'Grace Score : Risk of Death or MI in ACS Patients': 0.3, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.78, 'Respiratory Rate (breaths per minute) (RR)': 20, "Patient's Age": 70, 'Absolute Lymphocyte Count (ALC)': 2.9, 'Body Mass Index (kg/m²) (BMI)': 27.43, 'Brain Natriuretic Peptide (BNP)': 24.0, 'Chloride (mmol/L) (Cl)': 100, 'Kidney Function Marker (mg/dL) : Creatinine': 1.09, 'Diastolic Blood Pressure (mmHg) (DBP)': 70, 'Deceleration Time of Mitral Inflow (ms) (DT)': 207, 'Fractional Shortening (%) (FS)': 34, 'Hemoglobin (g/dL) (Hb)': 13.3, 'Glycated Hemoglobin (HbA1C)': 8.5, 'Bicarbonate (mmol/L) (HCO3)': 21, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.62, 'Heart Rate (HR)': 70, 'Invasive Coronary Treatment (ICT)': 59, 'Invasive Revascularization Therapy (IRT)': 118, 'Potassium (mmol/L) (K)': 4.1, 'Left Atrial Volume (mL) (LAV)': 38, 'Left Atrial Volume Index (mL/m²) (LAV)': 21.11, 'Low-Density Lipoprotein Cholesterol (LDLc)': 241, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 49, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 33, 'LVOT Velocity (LVOT VTI)': 24, 'Sodium (mmol/L) (Na)': 137, 'Random Blood Sugar (mg/dL) (RBS)': 12.1, 'Systolic Blood Pressure (mmHg) (SBP)': 120, 'Total Cholesterol (mg/dL) (TC)': 327, 'Triglycerides (mg/dL) (TG)': 271, 'Troponin I (TropI)': 6.1, 'Weight (kg)': 72, 'Obisity': 'Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 8: {'_id': ObjectId('67e6eb53c9af1619f7298415'), 'StudyID': 'MPI009', 'UHID': 462024, 'SN': 9, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' Yes', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Cardiomegaly', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'Yes', 'Left Ventricular Ejection Fraction (%) (LVEF)': 60, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.16, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': '   Female', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.4, 'Grace Score : Risk of Death or MI in ACS Patients': 0.2, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.86, 'Respiratory Rate (breaths per minute) (RR)': 20, "Patient's Age": 59, 'Absolute Lymphocyte Count (ALC)': 2.3, 'Body Mass Index (kg/m²) (BMI)': 25.39, 'Brain Natriuretic Peptide (BNP)': 26.0, 'Chloride (mmol/L) (Cl)': 101, 'Kidney Function Marker (mg/dL) : Creatinine': 0.85, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 143, 'Fractional Shortening (%) (FS)': 36, 'Hemoglobin (g/dL) (Hb)': 12.1, 'Glycated Hemoglobin (HbA1C)': 4.7, 'Bicarbonate (mmol/L) (HCO3)': 25, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.6, 'Heart Rate (HR)': 82, 'Invasive Coronary Treatment (ICT)': 74, 'Invasive Revascularization Therapy (IRT)': 92, 'Potassium (mmol/L) (K)': 4.3, 'Left Atrial Volume (mL) (LAV)': 30, 'Left Atrial Volume Index (mL/m²) (LAV)': 17.65, 'Low-Density Lipoprotein Cholesterol (LDLc)': 165, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 45, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 29, 'LVOT Velocity (LVOT VTI)': 21, 'Sodium (mmol/L) (Na)': 139, 'Random Blood Sugar (mg/dL) (RBS)': 6.1, 'Systolic Blood Pressure (mmHg) (SBP)': 140, 'Total Cholesterol (mg/dL) (TC)': 250, 'Triglycerides (mg/dL) (TG)': 210, 'Troponin I (TropI)': 0.001, 'Weight (kg)': 65, 'Obisity': 'No Obese', 'Chest_pain': 'Present', 'Heart Failure (HF)': '   No HF'}
# 9: {'_id': ObjectId('67e6eb53c9af1619f7298416'), 'StudyID': 'MPI010', 'UHID': 778732, 'SN': 10, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'Yes', 'Left Ventricular Ejection Fraction (%) (LVEF)': 64, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.14, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': '   Female', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.5, 'Grace Score : Risk of Death or MI in ACS Patients': 0.4, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   Mild symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 3.39, 'Respiratory Rate (breaths per minute) (RR)': 20, "Patient's Age": 70, 'Absolute Lymphocyte Count (ALC)': 1.8, 'Body Mass Index (kg/m²) (BMI)': 24.46, 'Brain Natriuretic Peptide (BNP)': 28.0, 'Chloride (mmol/L) (Cl)': 104, 'Kidney Function Marker (mg/dL) : Creatinine': 1.11, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 244, 'Fractional Shortening (%) (FS)': 17, 'Hemoglobin (g/dL) (Hb)': 11.1, 'Glycated Hemoglobin (HbA1C)': 5.9, 'Bicarbonate (mmol/L) (HCO3)': 26, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.63, 'Heart Rate (HR)': 102, 'Invasive Coronary Treatment (ICT)': 42, 'Invasive Revascularization Therapy (IRT)': 88, 'Potassium (mmol/L) (K)': 3.9, 'Left Atrial Volume (mL) (LAV)': 32, 'Left Atrial Volume Index (mL/m²) (LAV)': 18.6, 'Low-Density Lipoprotein Cholesterol (LDLc)': 150, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 49, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 41, 'LVOT Velocity (LVOT VTI)': 19, 'Sodium (mmol/L) (Na)': 129, 'Random Blood Sugar (mg/dL) (RBS)': 6.8, 'Systolic Blood Pressure (mmHg) (SBP)': 120, 'Total Cholesterol (mg/dL) (TC)': 210, 'Triglycerides (mg/dL) (TG)': 180, 'Troponin I (TropI)': 0.0004, 'Weight (kg)': 65, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 10: {'_id': ObjectId('67e6eb53c9af1619f7298417'), 'StudyID': 'MPI011', 'UHID': 412156, 'SN': 11, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 65, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.31, 'Mitral Regurgitation (MR)': '   Mild', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': '   Female', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.7, 'Grace Score : Risk of Death or MI in ACS Patients': 0.3, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   Moderate symptoms', 'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 1.24, 'Respiratory Rate (breaths per minute) (RR)': 25, "Patient's Age": 60, 'Absolute Lymphocyte Count (ALC)': 1.1, 'Body Mass Index (kg/m²) (BMI)': 27.76, 'Brain Natriuretic Peptide (BNP)': 30.0, 'Chloride (mmol/L) (Cl)': 104, 'Kidney Function Marker (mg/dL) : Creatinine': 1.02, 'Diastolic Blood Pressure (mmHg) (DBP)': 100, 'Deceleration Time of Mitral Inflow (ms) (DT)': 157, 'Fractional Shortening (%) (FS)': 21, 'Hemoglobin (g/dL) (Hb)': 12.6, 'Glycated Hemoglobin (HbA1C)': 6.3, 'Bicarbonate (mmol/L) (HCO3)': 27, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.75, 'Heart Rate (HR)': 71, 'Invasive Coronary Treatment (ICT)': 74, 'Invasive Revascularization Therapy (IRT)': 133, 'Potassium (mmol/L) (K)': 3.5, 'Left Atrial Volume (mL) (LAV)': 35, 'Left Atrial Volume Index (mL/m²) (LAV)': 20.0, 'Low-Density Lipoprotein Cholesterol (LDLc)': 101, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 63, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 50, 'LVOT Velocity (LVOT VTI)': 25, 'Sodium (mmol/L) (Na)': 140, 'Random Blood Sugar (mg/dL) (RBS)': 5.4, 'Systolic Blood Pressure (mmHg) (SBP)': 160, 'Total Cholesterol (mg/dL) (TC)': 161, 'Triglycerides (mg/dL) (TG)': 108, 'Troponin I (TropI)': 6.5, 'Weight (kg)': 85, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 11: {'_id': ObjectId('67e6eb53c9af1619f7298418'), 'StudyID': 'MPI012', 'UHID': 778366, 'SN': 12, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 62, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.33, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.4, 'Grace Score : Risk of Death or MI in ACS Patients': 0.2, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   Moderate symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 1.29, 'Respiratory Rate (breaths per minute) (RR)': 18, "Patient's Age": 54, 'Absolute Lymphocyte Count (ALC)': 2.1, 'Body Mass Index (kg/m²) (BMI)': 27.24, 'Brain Natriuretic Peptide (BNP)': 20.0, 'Chloride (mmol/L) (Cl)': 106, 'Kidney Function Marker (mg/dL) : Creatinine': 1.12, 'Diastolic Blood Pressure (mmHg) (DBP)': 90, 'Deceleration Time of Mitral Inflow (ms) (DT)': 249, 'Fractional Shortening (%) (FS)': 33, 'Hemoglobin (g/dL) (Hb)': 11.7, 'Glycated Hemoglobin (HbA1C)': 5.6, 'Bicarbonate (mmol/L) (HCO3)': 27, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.58, 'Heart Rate (HR)': 72, 'Invasive Coronary Treatment (ICT)': 96, 'Invasive Revascularization Therapy (IRT)': 133, 'Potassium (mmol/L) (K)': 3.2, 'Left Atrial Volume (mL) (LAV)': 27, 'Left Atrial Volume Index (mL/m²) (LAV)': 17.09, 'Low-Density Lipoprotein Cholesterol (LDLc)': 95, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 35, 'LVOT Velocity (LVOT VTI)': 27, 'Sodium (mmol/L) (Na)': 144, 'Random Blood Sugar (mg/dL) (RBS)': 5.2, 'Systolic Blood Pressure (mmHg) (SBP)': 130, 'Total Cholesterol (mg/dL) (TC)': 130, 'Triglycerides (mg/dL) (TG)': 75, 'Troponin I (TropI)': 0.0001, 'Weight (kg)': 68, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 12: {'_id': ObjectId('67e6eb53c9af1619f7298419'), 'StudyID': 'MPI013', 'UHID': 777895, 'SN': 13, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   Others', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'Yes', 'Left Ventricular Ejection Fraction (%) (LVEF)': 62, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.04, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': 'Ex', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.5, 'Grace Score : Risk of Death or MI in ACS Patients': 0.3, 'Major Adverse Cardiac Events  (MACES)': 11.6, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.61, 'Respiratory Rate (breaths per minute) (RR)': 25, "Patient's Age": 61, 'Absolute Lymphocyte Count (ALC)': 1.9, 'Body Mass Index (kg/m²) (BMI)': 35.2, 'Brain Natriuretic Peptide (BNP)': 25.0, 'Chloride (mmol/L) (Cl)': 107, 'Kidney Function Marker (mg/dL) : Creatinine': 1.15, 'Diastolic Blood Pressure (mmHg) (DBP)': 90, 'Deceleration Time of Mitral Inflow (ms) (DT)': 109, 'Fractional Shortening (%) (FS)': 32, 'Hemoglobin (g/dL) (Hb)': 12.5, 'Glycated Hemoglobin (HbA1C)': 5.3, 'Bicarbonate (mmol/L) (HCO3)': 22, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.45, 'Heart Rate (HR)': 84, 'Invasive Coronary Treatment (ICT)': 61, 'Invasive Revascularization Therapy (IRT)': 84, 'Potassium (mmol/L) (K)': 4.0, 'Left Atrial Volume (mL) (LAV)': 29, 'Left Atrial Volume Index (mL/m²) (LAV)': 16.76, 'Low-Density Lipoprotein Cholesterol (LDLc)': 165, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 36, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24, 'LVOT Velocity (LVOT VTI)': 17, 'Sodium (mmol/L) (Na)': 134, 'Random Blood Sugar (mg/dL) (RBS)': 5.4, 'Systolic Blood Pressure (mmHg) (SBP)': 130, 'Total Cholesterol (mg/dL) (TC)': 220, 'Triglycerides (mg/dL) (TG)': 195, 'Troponin I (TropI)': 0.003, 'Weight (kg)': 74, 'Obisity': 'Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 13: {'_id': ObjectId('67e6eb53c9af1619f729841a'), 'StudyID': 'MPI014', 'UHID': 85541, 'SN': 14, 'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   DVD', 'Chest X-ray (CXR)': '   Cardiomegaly', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   OMI', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'Yes', 'Left Ventricular Ejection Fraction (%) (LVEF)': 40, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.34, 'Mitral Regurgitation (MR)': '   Trivial', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'MI', 'Route of Thrombolysis Administration ( RTA)': '   Femoral Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': 'Male', 'Smoking Status': 'Ex', 'Wall Motion Abnormality (Wall)': '   Antero-Septal', 'Euro Score : Cardiac Surgery Risk Score': 19.0, 'Grace Score : Risk of Death or MI in ACS Patients': 3.3, 'Major Adverse Cardiac Events  (MACES)': 65.2, 'New York Heart Association (NYHA)': '   Mild symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.83, 'Respiratory Rate (breaths per minute) (RR)': 20, "Patient's Age": 54, 'Absolute Lymphocyte Count (ALC)': 2.2, 'Body Mass Index (kg/m²) (BMI)': 33.3, 'Brain Natriuretic Peptide (BNP)': 35.0, 'Chloride (mmol/L) (Cl)': 106, 'Kidney Function Marker (mg/dL) : Creatinine': 1.0, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 183, 'Fractional Shortening (%) (FS)': 32, 'Hemoglobin (g/dL) (Hb)': 11.3, 'Glycated Hemoglobin (HbA1C)': 5.3, 'Bicarbonate (mmol/L) (HCO3)': 22, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.55, 'Heart Rate (HR)': 100, 'Invasive Coronary Treatment (ICT)': 83, 'Invasive Revascularization Therapy (IRT)': 92, 'Potassium (mmol/L) (K)': 3.5, 'Left Atrial Volume (mL) (LAV)': 49, 'Left Atrial Volume Index (mL/m²) (LAV)': 26.4, 'Low-Density Lipoprotein Cholesterol (LDLc)': 170, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 51, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34, 'LVOT Velocity (LVOT VTI)': 20, 'Sodium (mmol/L) (Na)': 141, 'Random Blood Sugar (mg/dL) (RBS)': 6.4, 'Systolic Blood Pressure (mmHg) (SBP)': 120, 'Total Cholesterol (mg/dL) (TC)': 190, 'Triglycerides (mg/dL) (TG)': 210, 'Troponin I (TropI)': 0.003, 'Weight (kg)': 80, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   Killip II'}
# 14: {'_id': ObjectId('67e6eb53c9af1619f729841b'), 'StudyID': 'MPI015', 'UHID': 66562, 'SN': 15, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 65, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.18, 'Mitral Regurgitation (MR)': '   Trivial', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.4, 'Grace Score : Risk of Death or MI in ACS Patients': 0.1, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.51, 'Respiratory Rate (breaths per minute) (RR)': 21, "Patient's Age": 36, 'Absolute Lymphocyte Count (ALC)': 3.1, 'Body Mass Index (kg/m²) (BMI)': 27.34, 'Brain Natriuretic Peptide (BNP)': 20.0, 'Chloride (mmol/L) (Cl)': 101, 'Kidney Function Marker (mg/dL) : Creatinine': 0.91, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 92, 'Fractional Shortening (%) (FS)': 35, 'Hemoglobin (g/dL) (Hb)': 12.5, 'Glycated Hemoglobin (HbA1C)': 6.7, 'Bicarbonate (mmol/L) (HCO3)': 24, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.53, 'Heart Rate (HR)': 84, 'Invasive Coronary Treatment (ICT)': 83, 'Invasive Revascularization Therapy (IRT)': 65, 'Potassium (mmol/L) (K)': 4.0, 'Left Atrial Volume (mL) (LAV)': 49, 'Left Atrial Volume Index (mL/m²) (LAV)': 29.71, 'Low-Density Lipoprotein Cholesterol (LDLc)': 75, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 36, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24, 'LVOT Velocity (LVOT VTI)': 20, 'Sodium (mmol/L) (Na)': 135, 'Random Blood Sugar (mg/dL) (RBS)': 10.5, 'Systolic Blood Pressure (mmHg) (SBP)': 130, 'Total Cholesterol (mg/dL) (TC)': 150, 'Triglycerides (mg/dL) (TG)': 100, 'Troponin I (TropI)': 0.03, 'Weight (kg)': 64, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   Killip II'}
# 15: {'_id': ObjectId('67e6eb53c9af1619f729841c'), 'StudyID': 'MPI016', 'UHID': 778507, 'SN': 16, 'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   DVD', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   ST Depression', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 45, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.58, 'Mitral Regurgitation (MR)': '   Mild', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'MI', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': 'Male', 'Smoking Status': '   Current', 'Wall Motion Abnormality (Wall)': '   Antero-Septal', 'Euro Score : Cardiac Surgery Risk Score': 19.0, 'Grace Score : Risk of Death or MI in ACS Patients': 3.3, 'Major Adverse Cardiac Events  (MACES)': 65.2, 'New York Heart Association (NYHA)': '   Moderate symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 1.48, 'Respiratory Rate (breaths per minute) (RR)': 22, "Patient's Age": 60, 'Absolute Lymphocyte Count (ALC)': 2.1, 'Body Mass Index (kg/m²) (BMI)': 20.03, 'Brain Natriuretic Peptide (BNP)': 25.0, 'Chloride (mmol/L) (Cl)': 103, 'Kidney Function Marker (mg/dL) : Creatinine': 1.24, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 368, 'Fractional Shortening (%) (FS)': 36, 'Hemoglobin (g/dL) (Hb)': 13.1, 'Glycated Hemoglobin (HbA1C)': 4.3, 'Bicarbonate (mmol/L) (HCO3)': 24, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.58, 'Heart Rate (HR)': 82, 'Invasive Coronary Treatment (ICT)': 120, 'Invasive Revascularization Therapy (IRT)': 115, 'Potassium (mmol/L) (K)': 3.9, 'Left Atrial Volume (mL) (LAV)': 26, 'Left Atrial Volume Index (mL/m²) (LAV)': 17.55, 'Low-Density Lipoprotein Cholesterol (LDLc)': 175, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34, 'LVOT Velocity (LVOT VTI)': 38, 'Sodium (mmol/L) (Na)': 149, 'Random Blood Sugar (mg/dL) (RBS)': 5.8, 'Systolic Blood Pressure (mmHg) (SBP)': 140, 'Total Cholesterol (mg/dL) (TC)': 190, 'Triglycerides (mg/dL) (TG)': 170, 'Troponin I (TropI)': 0.03, 'Weight (kg)': 50, 'Obisity': 'No Obese', 'Chest_pain': 'Present', 'Heart Failure (HF)': '   Killip II'}
# 16: {'_id': ObjectId('67e6eb53c9af1619f729841d'), 'StudyID': 'MPI017', 'UHID': 399857, 'SN': 17, 'Acute Coronary Syndrome  (ACS)': '   ST-Elevation Myocardial Infarction (STEMI)', 'Irregular Heartbeat (Arrhythmia)': '   No Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '    Normal', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   Normal', 'Family History of Cardiovascular Disease (FH)': 'Yes', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 65, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.38, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'No', 'Gender of the Patient': 'Male', 'Smoking Status': '   Current', 'Wall Motion Abnormality (Wall)': 'No', 'Euro Score : Cardiac Surgery Risk Score': 0.6, 'Grace Score : Risk of Death or MI in ACS Patients': 0.3, 'Major Adverse Cardiac Events  (MACES)': 0.99, 'New York Heart Association (NYHA)': '   Moderate symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.8, 'Respiratory Rate (breaths per minute) (RR)': 20, "Patient's Age": 72, 'Absolute Lymphocyte Count (ALC)': 2.3, 'Body Mass Index (kg/m²) (BMI)': 28.52, 'Brain Natriuretic Peptide (BNP)': 15.0, 'Chloride (mmol/L) (Cl)': 100, 'Kidney Function Marker (mg/dL) : Creatinine': 0.95, 'Diastolic Blood Pressure (mmHg) (DBP)': 60, 'Deceleration Time of Mitral Inflow (ms) (DT)': 121, 'Fractional Shortening (%) (FS)': 35, 'Hemoglobin (g/dL) (Hb)': 14.2, 'Glycated Hemoglobin (HbA1C)': 8.9, 'Bicarbonate (mmol/L) (HCO3)': 27, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.6, 'Heart Rate (HR)': 78, 'Invasive Coronary Treatment (ICT)': 96, 'Invasive Revascularization Therapy (IRT)': 104, 'Potassium (mmol/L) (K)': 3.9, 'Left Atrial Volume (mL) (LAV)': 25, 'Left Atrial Volume Index (mL/m²) (LAV)': 15.63, 'Low-Density Lipoprotein Cholesterol (LDLc)': 65, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 43, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 28, 'LVOT Velocity (LVOT VTI)': 25, 'Sodium (mmol/L) (Na)': 138, 'Random Blood Sugar (mg/dL) (RBS)': 14.1, 'Systolic Blood Pressure (mmHg) (SBP)': 100, 'Total Cholesterol (mg/dL) (TC)': 120, 'Triglycerides (mg/dL) (TG)': 95, 'Troponin I (TropI)': 0.001, 'Weight (kg)': 73, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# ...
# 495: {'_id': ObjectId('67e6eb53c9af1619f72985fc'), 'StudyID': 'MPI496', 'UHID': 902570, 'SN': 496, 'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   TVD', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   AMI', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 45, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.1, 'Mitral Regurgitation (MR)': '   Nil', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': 'Male', 'Smoking Status': '   Current', 'Wall Motion Abnormality (Wall)': '   Antero-Lateral', 'Euro Score : Cardiac Surgery Risk Score': 1.9, 'Grace Score : Risk of Death or MI in ACS Patients': 10.0, 'Major Adverse Cardiac Events  (MACES)': 65.2, 'New York Heart Association (NYHA)': '   Severe symptoms', 'ST-Segment Resolution  (STR)': '   Partial Resolution (<=50%)', 'Thrombolysis': '     STK/TNK', 'E/A Ratio (E/A)': 0.9, 'Respiratory Rate (breaths per minute) (RR)': 22, "Patient's Age": 35, 'Absolute Lymphocyte Count (ALC)': 1.3, 'Body Mass Index (kg/m²) (BMI)': 29.38, 'Brain Natriuretic Peptide (BNP)': 12.0, 'Chloride (mmol/L) (Cl)': 99, 'Kidney Function Marker (mg/dL) : Creatinine': 1.24, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 178, 'Fractional Shortening (%) (FS)': 18, 'Hemoglobin (g/dL) (Hb)': 11.0, 'Glycated Hemoglobin (HbA1C)': 5.3, 'Bicarbonate (mmol/L) (HCO3)': 28, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.51, 'Heart Rate (HR)': 94, 'Invasive Coronary Treatment (ICT)': 92, 'Invasive Revascularization Therapy (IRT)': 94, 'Potassium (mmol/L) (K)': 3.8, 'Left Atrial Volume (mL) (LAV)': 33, 'Left Atrial Volume Index (mL/m²) (LAV)': 19.69, 'Low-Density Lipoprotein Cholesterol (LDLc)': 105, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 48, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 47, 'LVOT Velocity (LVOT VTI)': 21, 'Sodium (mmol/L) (Na)': 141, 'Random Blood Sugar (mg/dL) (RBS)': 6.1, 'Systolic Blood Pressure (mmHg) (SBP)': 110, 'Total Cholesterol (mg/dL) (TC)': 145, 'Triglycerides (mg/dL) (TG)': 110, 'Troponin I (TropI)': 13.25, 'Weight (kg)': 67, 'Obisity': 'No Obese', 'Chest_pain': 'Present', 'Heart Failure (HF)': '   Killip III'}
# 496: {'_id': ObjectId('67e6eb53c9af1619f72985fd'), 'StudyID': 'MPI497', 'UHID': 903670, 'SN': 497, 'Acute Coronary Syndrome  (ACS)': '   Non-ST-Elevation Myocardial Infarction (NSTEMI)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   TVD', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   T inversion', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 45, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.25, 'Mitral Regurgitation (MR)': '   Trivial', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'MI', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': 'Male', 'Smoking Status': 'Ex', 'Wall Motion Abnormality (Wall)': '   Subendocardial', 'Euro Score : Cardiac Surgery Risk Score': 4.5, 'Grace Score : Risk of Death or MI in ACS Patients': 2.6, 'Major Adverse Cardiac Events  (MACES)': 65.2, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 0.83, 'Respiratory Rate (breaths per minute) (RR)': 23, "Patient's Age": 55, 'Absolute Lymphocyte Count (ALC)': 2.6, 'Body Mass Index (kg/m²) (BMI)': 25.43, 'Brain Natriuretic Peptide (BNP)': 35.0, 'Chloride (mmol/L) (Cl)': 104, 'Kidney Function Marker (mg/dL) : Creatinine': 1.3, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 216, 'Fractional Shortening (%) (FS)': 48, 'Hemoglobin (g/dL) (Hb)': 12.1, 'Glycated Hemoglobin (HbA1C)': 5.7, 'Bicarbonate (mmol/L) (HCO3)': 24, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.43, 'Heart Rate (HR)': 70, 'Invasive Coronary Treatment (ICT)': 102, 'Invasive Revascularization Therapy (IRT)': 135, 'Potassium (mmol/L) (K)': 3.5, 'Left Atrial Volume (mL) (LAV)': 33, 'Left Atrial Volume Index (mL/m²) (LAV)': 22.96, 'Low-Density Lipoprotein Cholesterol (LDLc)': 105, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 48, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 24, 'LVOT Velocity (LVOT VTI)': 22, 'Sodium (mmol/L) (Na)': 149, 'Random Blood Sugar (mg/dL) (RBS)': 7.8, 'Systolic Blood Pressure (mmHg) (SBP)': 120, 'Total Cholesterol (mg/dL) (TC)': 160, 'Triglycerides (mg/dL) (TG)': 132, 'Troponin I (TropI)': 0.223, 'Weight (kg)': 52, 'Obisity': 'No Obese', 'Chest_pain': 'Absent', 'Heart Failure (HF)': '   No HF'}
# 497: {'_id': ObjectId('67e6eb53c9af1619f72985fe'), 'StudyID': 'MPI498', 'UHID': 907432, 'SN': 498, 'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   DVD', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   AMI', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'No', 'Left Ventricular Ejection Fraction (%) (LVEF)': 40, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.09, 'Mitral Regurgitation (MR)': '   Mild', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': 'Male', 'Smoking Status': '   Current', 'Wall Motion Abnormality (Wall)': '   Infero+Posterior', 'Euro Score : Cardiac Surgery Risk Score': 22.0, 'Grace Score : Risk of Death or MI in ACS Patients': 2.1, 'Major Adverse Cardiac Events  (MACES)': 65.2, 'New York Heart Association (NYHA)': '   Mild symptoms', 'ST-Segment Resolution  (STR)': '   Partial Resolution (<=50%)', 'Thrombolysis': '   Pharmacoinvasive', 'E/A Ratio (E/A)': 0.79, 'Respiratory Rate (breaths per minute) (RR)': 24, "Patient's Age": 70, 'Absolute Lymphocyte Count (ALC)': 0.84, 'Body Mass Index (kg/m²) (BMI)': 26.84, 'Brain Natriuretic Peptide (BNP)': 15.0, 'Chloride (mmol/L) (Cl)': 95, 'Kidney Function Marker (mg/dL) : Creatinine': 1.51, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 203, 'Fractional Shortening (%) (FS)': 20, 'Hemoglobin (g/dL) (Hb)': 10.1, 'Glycated Hemoglobin (HbA1C)': 10.5, 'Bicarbonate (mmol/L) (HCO3)': 20, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.52, 'Heart Rate (HR)': 78, 'Invasive Coronary Treatment (ICT)': 88, 'Invasive Revascularization Therapy (IRT)': 129, 'Potassium (mmol/L) (K)': 3.9, 'Left Atrial Volume (mL) (LAV)': 28, 'Left Atrial Volume Index (mL/m²) (LAV)': 17.28, 'Low-Density Lipoprotein Cholesterol (LDLc)': 160, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 52, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 42, 'LVOT Velocity (LVOT VTI)': 23, 'Sodium (mmol/L) (Na)': 139, 'Random Blood Sugar (mg/dL) (RBS)': 16.1, 'Systolic Blood Pressure (mmHg) (SBP)': 130, 'Total Cholesterol (mg/dL) (TC)': 225, 'Triglycerides (mg/dL) (TG)': 105, 'Troponin I (TropI)': 9.1, 'Weight (kg)': 62, 'Obisity': 'No Obese', 'Chest_pain': 'Present', 'Heart Failure (HF)': '   Killip II'}
# 498: {'_id': ObjectId('67e6eb53c9af1619f72985ff'), 'StudyID': 'MPI499', 'UHID': 941097, 'SN': 499, 'Acute Coronary Syndrome  (ACS)': '   Non-ST-Elevation Myocardial Infarction (NSTEMI)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   TVD with LM', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'Yes', 'Diabetes Mellitus (DM)': 'Yes', 'Electrocardiogram (ECG)': '   T inversion', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'Yes', 'Left Ventricular Ejection Fraction (%) (LVEF)': 20, 'Myocardial Infarction (Heart Attack) (MI)': 'Yes', 'Myocardial Performance Index ( MPI)': 0.17, 'Mitral Regurgitation (MR)': '   Trivial', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': '   Female', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': '   Subendocardial', 'Euro Score : Cardiac Surgery Risk Score': 19.5, 'Grace Score : Risk of Death or MI in ACS Patients': 20.0, 'Major Adverse Cardiac Events  (MACES)': 65.2, 'New York Heart Association (NYHA)': '   No symptoms', 'ST-Segment Resolution  (STR)': '   No Resolution', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 3.93, 'Respiratory Rate (breaths per minute) (RR)': 24, "Patient's Age": 38, 'Absolute Lymphocyte Count (ALC)': 3.6, 'Body Mass Index (kg/m²) (BMI)': 19.14, 'Brain Natriuretic Peptide (BNP)': 38.0, 'Chloride (mmol/L) (Cl)': 105, 'Kidney Function Marker (mg/dL) : Creatinine': 1.12, 'Diastolic Blood Pressure (mmHg) (DBP)': 80, 'Deceleration Time of Mitral Inflow (ms) (DT)': 107, 'Fractional Shortening (%) (FS)': 34, 'Hemoglobin (g/dL) (Hb)': 13.1, 'Glycated Hemoglobin (HbA1C)': 5.4, 'Bicarbonate (mmol/L) (HCO3)': 30, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.6, 'Heart Rate (HR)': 110, 'Invasive Coronary Treatment (ICT)': 148, 'Invasive Revascularization Therapy (IRT)': 134, 'Potassium (mmol/L) (K)': 4.1, 'Left Atrial Volume (mL) (LAV)': 24, 'Left Atrial Volume Index (mL/m²) (LAV)': 16.22, 'Low-Density Lipoprotein Cholesterol (LDLc)': 164, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 47, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 34, 'LVOT Velocity (LVOT VTI)': 8, 'Sodium (mmol/L) (Na)': 136, 'Random Blood Sugar (mg/dL) (RBS)': 5.8, 'Systolic Blood Pressure (mmHg) (SBP)': 120, 'Total Cholesterol (mg/dL) (TC)': 220, 'Triglycerides (mg/dL) (TG)': 236, 'Troponin I (TropI)': 0.08, 'Weight (kg)': 49, 'Obisity': 'No Obese', 'Chest_pain': 'Present', 'Heart Failure (HF)': '   No HF'}
# 499: {'_id': ObjectId('67e6eb53c9af1619f7298600'), 'StudyID': 'MPI500', 'UHID': 973812, 'SN': 500, 'Acute Coronary Syndrome  (ACS)': '   Unstable Angina (UA)', 'Irregular Heartbeat (Arrhythmia)': '   Arrhythmia', 'Bronchial Asthma (BA)': ' No', 'Coronary Artery Disease (CAD)': '   TVD', 'Chest X-ray (CXR)': '   Normal', 'Dyslipidemia : Abnormal Cholesterol Levels (DL)': 'No', 'Diabetes Mellitus (DM)': 'No', 'Electrocardiogram (ECG)': '   AMI', 'Family History of Cardiovascular Disease (FH)': 'No', 'Hypertension (HTN)': 'Yes', 'Left Ventricular Ejection Fraction (%) (LVEF)': 30, 'Myocardial Infarction (Heart Attack) (MI)': 'No', 'Myocardial Performance Index ( MPI)': 0.13, 'Mitral Regurgitation (MR)': '   Trivial', 'Rhythm of Pulse (RP)': '   Regular', 'Recurrent Myocardial Infarction (ReMI)': 'No', 'Route of Thrombolysis Administration ( RTA)': '   Radial Route', 'Regional Wall Motion Abnormality (RWMA)': 'Yes', 'Gender of the Patient': '   Female', 'Smoking Status': 'No', 'Wall Motion Abnormality (Wall)': '   Anterior', 'Euro Score : Cardiac Surgery Risk Score': 8.1, 'Grace Score : Risk of Death or MI in ACS Patients': 3.5, 'Major Adverse Cardiac Events  (MACES)': 65.2, 'New York Heart Association (NYHA)': '   Moderate symptoms', 'ST-Segment Resolution  (STR)': '   Resolution ( >=50%)', 'Thrombolysis': '   N/A', 'E/A Ratio (E/A)': 1.32, 'Respiratory Rate (breaths per minute) (RR)': 25, "Patient's Age": 60, 'Absolute Lymphocyte Count (ALC)': 2.5, 'Body Mass Index (kg/m²) (BMI)': 20.83, 'Brain Natriuretic Peptide (BNP)': 25.0, 'Chloride (mmol/L) (Cl)': 106, 'Kidney Function Marker (mg/dL) : Creatinine': 3.4, 'Diastolic Blood Pressure (mmHg) (DBP)': 60, 'Deceleration Time of Mitral Inflow (ms) (DT)': 211, 'Fractional Shortening (%) (FS)': 24, 'Hemoglobin (g/dL) (Hb)': 14.5, 'Glycated Hemoglobin (HbA1C)': 5.2, 'Bicarbonate (mmol/L) (HCO3)': 25, 'High-Density Lipoprotein Cholesterol (HDLc)': 'Risk', 'Height (cm or m)': 1.61, 'Heart Rate (HR)': 98, 'Invasive Coronary Treatment (ICT)': 92, 'Invasive Revascularization Therapy (IRT)': 130, 'Potassium (mmol/L) (K)': 3.8, 'Left Atrial Volume (mL) (LAV)': 31, 'Left Atrial Volume Index (mL/m²) (LAV)': 19.95, 'Low-Density Lipoprotein Cholesterol (LDLc)': 90, 'Left Ventricular Internal Diameter in Diastole (mm) (LVIDd)': 60, 'Left Ventricular Internal Diameter in Systole (mm) (LVIDs)': 46, 'LVOT Velocity (LVOT VTI)': 21, 'Sodium (mmol/L) (Na)': 137, 'Random Blood Sugar (mg/dL) (RBS)': 10.0, 'Systolic Blood Pressure (mmHg) (SBP)': 90, 'Total Cholesterol (mg/dL) (TC)': 110, 'Triglycerides (mg/dL) (TG)': 80, 'Troponin I (TropI)': 9.17, 'Weight (kg)': 54, 'Obisity': 'No Obese', 'Chest_pain': 'Present', 'Heart Failure (HF)': '   Killip II'}

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id StudyID    UHID  SN  \
# 0  67e6eb53c9af1619f729840d  MPI001  205179   1
# 1  67e6eb53c9af1619f729840e  MPI002  311074   2
# 2  67e6eb53c9af1619f729840f  MPI003  530942   3
# 3  67e6eb53c9af1619f7298410  MPI004    3414   4
# 4  67e6eb53c9af1619f7298411  MPI005  777747   5
#
#                   Acute Coronary Syndrome  (ACS)  \
# 0     ST-Elevation Myocardial Infarction (STEMI)
# 1     ST-Elevation Myocardial Infarction (STEMI)
# 2     ST-Elevation Myocardial Infarction (STEMI)
# 3     ST-Elevation Myocardial Infarction (STEMI)
# 4     ST-Elevation Myocardial Infarction (STEMI)
#
#   Irregular Heartbeat (Arrhythmia) Bronchial Asthma (BA)  \
# 0                    No Arrhythmia                    No
# 1                    No Arrhythmia                    No
# 2                    No Arrhythmia                    No
# 3                    No Arrhythmia                    No
# 4                    No Arrhythmia                    No
#
#   Coronary Artery Disease (CAD) Chest X-ray (CXR)  \
# 0                        Normal            Normal
# 1                        Normal            Normal
# 2                        Normal            Normal
# 3                        Normal            Normal
# 4                        Normal            Normal
#
#   Dyslipidemia : Abnormal Cholesterol Levels (DL)  ... Sodium (mmol/L) (Na)  \
# 0                                              No  ...                  140
# 1                                              No  ...                  137
# 2                                              No  ...                  139
# 3                                              No  ...                  141
# 4                                             Yes  ...                  141
#
#   Random Blood Sugar (mg/dL) (RBS) Systolic Blood Pressure (mmHg) (SBP)  \
# 0                              4.9                                  180
# 1                              6.5                                  140
# 2                              4.9                                  140
# 3                              5.4                                  130
# 4                              6.0                                  130
#
#   Total Cholesterol (mg/dL) (TC)  Triglycerides (mg/dL) (TG)  \
# 0                            100                          95
# 1                            110                          85
# 2                            130                         100
# 3                            135                         120
# 4                            220                         190
#
#   Troponin I (TropI)  Weight (kg)   Obisity Chest_pain Heart Failure (HF)
# 0              0.001           60     Obese     Absent              No HF
# 1              0.005           64  No Obese     Absent              No HF
# 2              6.500           85  No Obese     Absent              No HF
# 3              0.001           66  No Obese     Absent              No HF
# 4              0.003           70     Obese     Absent              No HF
#
# [5 rows x 67 columns]

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()
# Out:
#   StudyID    UHID  SN                 Acute Coronary Syndrome  (ACS)  \
# 0  MPI001  205179   1     ST-Elevation Myocardial Infarction (STEMI)
# 1  MPI002  311074   2     ST-Elevation Myocardial Infarction (STEMI)
# 2  MPI003  530942   3     ST-Elevation Myocardial Infarction (STEMI)
# 3  MPI004    3414   4     ST-Elevation Myocardial Infarction (STEMI)
# 4  MPI005  777747   5     ST-Elevation Myocardial Infarction (STEMI)
#
#   Irregular Heartbeat (Arrhythmia) Bronchial Asthma (BA)  \
# 0                    No Arrhythmia                    No
# 1                    No Arrhythmia                    No
# 2                    No Arrhythmia                    No
# 3                    No Arrhythmia                    No
# 4                    No Arrhythmia                    No
#
#   Coronary Artery Disease (CAD) Chest X-ray (CXR)  \
# 0                        Normal            Normal
# 1                        Normal            Normal
# 2                        Normal            Normal
# 3                        Normal            Normal
# 4                        Normal            Normal
#
#   Dyslipidemia : Abnormal Cholesterol Levels (DL) Diabetes Mellitus (DM)  ...  \
# 0                                              No                     No  ...
# 1                                              No                     No  ...
# 2                                              No                     No  ...
# 3                                              No                    Yes  ...
# 4                                             Yes                     No  ...
#
#   Sodium (mmol/L) (Na) Random Blood Sugar (mg/dL) (RBS)  \
# 0                  140                              4.9
# 1                  137                              6.5
# 2                  139                              4.9
# 3                  141                              5.4
# 4                  141                              6.0
#
#   Systolic Blood Pressure (mmHg) (SBP)  Total Cholesterol (mg/dL) (TC)  \
# 0                                  180                             100
# 1                                  140                             110
# 2                                  140                             130
# 3                                  130                             135
# 4                                  130                             220
#
#   Triglycerides (mg/dL) (TG)  Troponin I (TropI) Weight (kg)   Obisity  \
# 0                         95               0.001          60     Obese
# 1                         85               0.005          64  No Obese
# 2                        100               6.500          85  No Obese
# 3                        120               0.001          66  No Obese
# 4                        190               0.003          70     Obese
#
#   Chest_pain Heart Failure (HF)
# 0     Absent              No HF
# 1     Absent              No HF
# 2     Absent              No HF
# 3     Absent              No HF
# 4     Absent              No HF
#
# [5 rows x 66 columns]
