# %%
print("ok")
# Out:
# ok

# %%
'''mongodb+srv://khalidasdsju:<db_password>@cluster0.wh4fymj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''
# Out:
# 'mongodb+srv://khalidasdsju:<db_password>@cluster0.wh4fymj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0\n'

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_spss("your_file_name.sav")
df.head()
# Out:
#   StudyID   Age     Sex    BMI NYHA    HR  HTN   DM Smoker   DL  ...     DT  \
# 0  MPI149  50.0  Female  28.72    I  74.0  Yes  Yes    Yes  Yes  ...  192.0
# 1  MPI188  74.0    Male  23.88    I  84.0   No  Yes     No  Yes  ...  157.0
# 2  MPI019  51.0    Male  25.24    I  78.0   No  Yes     No  Yes  ...  181.0
# 3  MPI046  68.0    Male  27.85    I  72.0  Yes  Yes     No   No  ...  192.0
# 4  MPI063  34.0    Male  21.61    I  72.0   No   No    Yes   No  ...  159.0
#
#     MPI    RR  Chest_pain     TC   LDLc  HDLc     TG   BNP     HF
# 0  0.53  26.0      Absent  279.0  212.0  42.0  124.0   5.0  No HF
# 1  0.16  20.0      Absent  143.0   87.0  27.0  170.0   5.0  No HF
# 2  0.09  20.0      Absent  135.0   78.0  32.0   99.0  10.0  No HF
# 3  0.02  20.0      Absent  135.0   97.0  38.0  120.0  10.0  No HF
# 4  0.03  20.0      Absent  180.0   90.0  34.0  120.0  10.0  No HF
#
# [5 rows x 45 columns]

# %%
df.shape
# Out:
# (500, 45)

# %%
df.columns
# Out:
# Index(['StudyID', 'Age', 'Sex', 'BMI', 'NYHA', 'HR', 'HTN', 'DM', 'Smoker',
#        'DL', 'BA', 'RBS', 'HbA1C', 'Creatinine', 'Na', 'K', 'Cl', 'Hb',
#        'TropI', 'CXR', 'ECG', 'LVIDd', 'FS', 'LVIDs', 'LVEF', 'RWMA', 'LAV',
#        'MI', 'ACS', 'Wall', 'Thrombolysis', 'ICT', 'IRT', 'MR', 'EA', 'DT',
#        'MPI', 'RR', 'Chest_pain', 'TC', 'LDLc', 'HDLc', 'TG', 'BNP', 'HF'],
#       dtype='object')

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'StudyID': 'MPI149',
#   'Age': 50.0,
#   'Sex': 'Female',
#   'BMI': 28.72,
#   'NYHA': 'I',
#   'HR': 74.0,
#   'HTN': 'Yes',
#   'DM': 'Yes',
#   'Smoker': 'Yes',
#   'DL': 'Yes',
#   'BA': 'No',
#   'RBS': 8.2,
#   'HbA1C': 6.5,
#   'Creatinine': 1.15,
#   'Na': 149.0,
#   'K': 3.9,
#   'Cl': 99.0,
#   'Hb': 12.1,
#   'TropI': 8.5,
#   'CXR': 'Normal',
#   'ECG': 'Others',
#   'LVIDd': 49.0,
#   'FS': 33.0,
#   'LVIDs': 31.0,
#   'LVEF': 35.0,
#   'RWMA': 'Yes',
#   'LAV': 45.0,
#   'MI': 'Yes',
#   'ACS': 'NSTEMI',
#   'Wall': 'Subendocardial',
#   'Thrombolysis': 'N/A',
#   'ICT': 116.0,
#   'IRT': 121.0,
#   'MR': 'Nil',
#   'EA': 1.16,
#   'DT': 192.0,
#   'MPI': 0.53,
#   'RR': 26.0,
#   'Chest_pain': 'Absent',
#   'TC': 279.0,
#   'LDLc': 212.0,
#   'HDLc': 42.0,
#   'TG': 124.0,
#   'BNP': 5.0,
#   'HF': 'No HF'},
#  {'StudyID': 'MPI188',
#   'Age': 74.0,
#   'Sex': 'Male',
#   'BMI': 23.88,
#   'NYHA': 'I',
#   'HR': 84.0,
#   'HTN': 'No',
#   'DM': 'Yes',
# ...

# %%
len(data)
# Out:
# 500

# %%
DB_NAME = "Study_Data"
COLLECTION_NAME = "Study_Data"
CONNECTION_URL = "mongodb+srv://khalidasdsju:khalidasdsju@cluster0.wh4fymj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('67f0d1bbb3b69c6d46f4d869'), 'StudyID': 'MPI149', 'Age': 50.0, 'Sex': 'Female', 'BMI': 28.72, 'NYHA': 'I', 'HR': 74.0, 'HTN': 'Yes', 'DM': 'Yes', 'Smoker': 'Yes', 'DL': 'Yes', 'BA': 'No', 'RBS': 8.2, 'HbA1C': 6.5, 'Creatinine': 1.15, 'Na': 149.0, 'K': 3.9, 'Cl': 99.0, 'Hb': 12.1, 'TropI': 8.5, 'CXR': 'Normal', 'ECG': 'Others', 'LVIDd': 49.0, 'FS': 33.0, 'LVIDs': 31.0, 'LVEF': 35.0, 'RWMA': 'Yes', 'LAV': 45.0, 'MI': 'Yes', 'ACS': 'NSTEMI', 'Wall': 'Subendocardial', 'Thrombolysis': 'N/A', 'ICT': 116.0, 'IRT': 121.0, 'MR': 'Nil', 'EA': 1.16, 'DT': 192.0, 'MPI': 0.53, 'RR': 26.0, 'Chest_pain': 'Absent', 'TC': 279.0, 'LDLc': 212.0, 'HDLc': 42.0, 'TG': 124.0, 'BNP': 5.0, 'HF': 'No HF'}
# ...

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id StudyID   Age     Sex    BMI NYHA    HR  HTN   DM  \
# 0  67f0d1bbb3b69c6d46f4d869  MPI149  50.0  Female  28.72    I  74.0  Yes  Yes
# 1  67f0d1bbb3b69c6d46f4d86a  MPI188  74.0    Male  23.88    I  84.0   No  Yes
# 2  67f0d1bbb3b69c6d46f4d86b  MPI019  51.0    Male  25.24    I  78.0   No  Yes
# 3  67f0d1bbb3b69c6d46f4d86c  MPI046  68.0    Male  27.85    I  72.0  Yes  Yes
# 4  67f0d1bbb3b69c6d46f4d86d  MPI063  34.0    Male  21.61    I  72.0   No   No
#
#   Smoker  ...     DT   MPI    RR  Chest_pain     TC   LDLc  HDLc     TG   BNP  \
# 0    Yes  ...  192.0  0.53  26.0      Absent  279.0  212.0  42.0  124.0   5.0
# 1     No  ...  157.0  0.16  20.0      Absent  143.0   87.0  27.0  170.0   5.0
# 2     No  ...  181.0  0.09  20.0      Absent  135.0   78.0  32.0   99.0  10.0
# 3     No  ...  192.0  0.02  20.0      Absent  135.0   97.0  38.0  120.0  10.0
# 4    Yes  ...  159.0  0.03  20.0      Absent  180.0   90.0  34.0  120.0  10.0
#
#       HF
# 0  No HF
# ...

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()
# Out:
#   StudyID   Age     Sex    BMI NYHA    HR  HTN   DM Smoker   DL  ...     DT  \
# 0  MPI149  50.0  Female  28.72    I  74.0  Yes  Yes    Yes  Yes  ...  192.0
# 1  MPI188  74.0    Male  23.88    I  84.0   No  Yes     No  Yes  ...  157.0
# 2  MPI019  51.0    Male  25.24    I  78.0   No  Yes     No  Yes  ...  181.0
# 3  MPI046  68.0    Male  27.85    I  72.0  Yes  Yes     No   No  ...  192.0
# 4  MPI063  34.0    Male  21.61    I  72.0   No   No    Yes   No  ...  159.0
#
#     MPI    RR  Chest_pain     TC   LDLc  HDLc     TG   BNP     HF
# 0  0.53  26.0      Absent  279.0  212.0  42.0  124.0   5.0  No HF
# 1  0.16  20.0      Absent  143.0   87.0  27.0  170.0   5.0  No HF
# 2  0.09  20.0      Absent  135.0   78.0  32.0   99.0  10.0  No HF
# 3  0.02  20.0      Absent  135.0   97.0  38.0  120.0  10.0  No HF
# 4  0.03  20.0      Absent  180.0   90.0  34.0  120.0  10.0  No HF
#
# [5 rows x 45 columns]
